# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>10. High Level Charts</h2></div>

# %% [markdown]
# This section covers the `bokeh.charts` interface, which is a high-level API that is especially useful for exploratory data analysis (for instance, in a Jupyter notebook). It provides functions for quickly producing many standard chart types, often with a single line of code. We will look at the following types in this notebook:
#
# * [Scatter Plot](#Scatter-Plot)
# * [Bar Chart](#Bar-Chart)
# * [Histogram](#Histogram)
# * [Box Plot](#Box-Plot)

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="87f27069-e46f-4990-bdc4-0bd9b8a48a3c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Scatter Plot
#
# A high-level scatter plot is provided by [`bokeh.charts.Scatter`]().
#
# For this section will use the "iris" data set. First let's import it and take a look at a few rows:

# %%
from bokeh.sampledata.iris import flowers
flowers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from bokeh.charts import Scatter
# Out:
# C:\Users\ZekeLabs\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)

# %% [markdown]
# A basic scatter chart takes the data (in this case a pandas DataFrame) as the first argument, and specifies the `x` and `y` coordinates for the scatter as the names of columns in the data.

# %%
p = Scatter(flowers, x='petal_length', y='petal_width')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4f064852-a4c1-4728-b13f-2ce5afac7a23"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4f064852-a4c1-4728-b13f-2ce5afac7a23");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4f064852-a4c1-4728-b13f-2ce5afac7a23");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4f064852-a4c1-4728-b13f-2ce5afac7a23' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fa738492-c2bc-404d-abd6-1c5d7cd40233":{"roots":{"references":[{"attributes":{"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"}},"id":"563a6f90-345d-491b-ba19-0bd97cea29b8","type":"ResetTool"},{"attributes":{"axis_label":"petal_length","formatter":{"id":"3e2e199a-8db4-44fd-86ef-f1194c5516ba","type":"BasicTickFormatter"},"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"},"ticker":{"id":"0b2bf38b-8313-4115-b059-aa38c6eb6ac9","type":"BasicTicker"}},"id":"aaa9639f-088d-4406-ba3b-9b402db5f706","type":"LinearAxis"},{"attributes":{},"id":"dc98d14e-8f88-4847-bc1b-116fbe244f41","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"33df6e2a-a71c-4903-b0e7-02d2b7f21d17","type":"PanTool"},{"id":"00076f3b-5ba9-42fe-909b-2c4ffd7fada4","type":"WheelZoomTool"},{"id":"917272e7-ead7-4c64-bb06-c6ed7bef285e","type":"BoxZoomTool"},{"id":"12e761c8-3f6a-4c7e-97e8-21a7909acfdd","type":"SaveTool"},{"id":"563a6f90-345d-491b-ba19-0bd97cea29b8","type":"ResetTool"},{"id":"8a2e8d17-77c5-4be4-9b5d-2b97808332b6","type":"HelpTool"}]},"id":"71714fae-006b-42a6-bd78-a92f4c2938b5","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"fb92ef9a-0a23-49c9-9969-ede71e05839c","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"a8f39b6c-dbe0-4a7a-9a50-cf7d149271b5","type":"ColumnDataSource"},"glyph":{"id":"1f6e1099-6aba-4489-ba7f-377ab4b2a8a6","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"ce4e072f-7d7d-44e8-8e46-d61bd66a07b2","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":2.74,"start":-0.13999999999999999},"id":"691ffc18-d0d4-4971-be80-277c5c87007a","type":"Range1d"},{"attributes":{"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"}},"id":"00076f3b-5ba9-42fe-909b-2c4ffd7fada4","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"},"ticker":{"id":"05e8b06e-e1d2-49d7-9fcd-be931febfa0c","type":"BasicTicker"}},"id":"18c40fb2-596b-444e-b338-d18c8e1bc2aa","type":"Grid"},{"attributes":{"overlay":{"id":"fb92ef9a-0a23-49c9-9969-ede71e05839c","type":"BoxAnnotation"},"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"}},"id":"917272e7-ead7-4c64-bb06-c6ed7bef285e","type":"BoxZoomTool"},{"attributes":{"axis_label":"petal_width","formatter":{"id":"dc98d14e-8f88-4847-bc1b-116fbe244f41","type":"BasicTickFormatter"},"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"},"ticker":{"id":"05e8b06e-e1d2-49d7-9fcd-be931febfa0c","type":"BasicTicker"}},"id":"acb10433-df8b-4c05-b7d0-46e889faacad","type":"LinearAxis"},{"attributes":{},"id":"137d1a08-265e-4c47-9d3e-56e9f1554f5e","type":"LinearScale"},{"attributes":{"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"},"ticker":{"id":"0b2bf38b-8313-4115-b059-aa38c6eb6ac9","type":"BasicTicker"}},"id":"31b82ffd-2fa1-4595-aed3-19ef5791caaf","type":"Grid"},{"attributes":{"plot":{"id":"90baf520-abdb-46ca-97a4-0654496b9d72","subtype":"Chart","type":"Plot"}},"id":"8a2e8d17-77c5-4be4-9b5d-2b97808332b6","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null ...

# %% [markdown]
# By passing a column name for the `color` parameter, you can make `Scatter` automatically color the markers according to the groups in that column. Let's also add a legend by specify its location as the value of a `legend` paramter (in this case `"top_left"`)

# %%
p = Scatter(flowers, x='petal_length', y='petal_width', color='species', legend='top_left')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b4316524-0a34-4cfa-8b5f-d8d744236184"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b4316524-0a34-4cfa-8b5f-d8d744236184");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b4316524-0a34-4cfa-8b5f-d8d744236184");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b4316524-0a34-4cfa-8b5f-d8d744236184' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"67dbf158-14ec-4854-8175-928b1a2de705":{"roots":{"references":[{"attributes":{"plot":{"id":"4d183106-5ac7-4d14-ba7c-d720d4cf7cc0","subtype":"Chart","type":"Plot"}},"id":"58002f8e-10f5-48df-a94f-93e430d1a2c3","type":"PanTool"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"}],"species":["versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor"],"x_values":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y_values":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"8cc2beed-9c63-49ee-a4c4-6d13dd7d8545","type":"ColumnDataSource"},{"attributes":{"axis_label":"petal_length","formatter":{"id":"44631390-affc-4580-8ecb-4d86d6269ee2","type":"BasicTickFormatter"},"plot":{"id":"4d183106-5ac7-4d14-ba7c-d720d4cf7cc0","subtype":"Chart","type":"Plot"},"ticker":{"id":"7cb73a31-8996-4bb2-8b09-42ba8b9f1072","type":"BasicTicker"}},"id":"f44c1419-3ac1-4a09-bf81-df6e5d6aefda","type":"LinearAxis"},{"attributes":{},"id":"5efeb7ed-0d48-4ca1-8da1-73c25f7b2f73","type":"LinearScale"},{"attributes":{"callback":null,"end":7.49,"start":0.4099999999999999},"id":"12fe32e9-393a-4585-90e2-cbc19b9edbb8","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"42b65b66-c12b-456a-8221-0281aefa577a","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"53d2bd09-dd0a-488a-b7c2-f07ee9eabc49","type":"Circle"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"}, ...

# %% [markdown]
# By passing a column name for the `marker` parameter, you can make `Scatter` automatically vary the marker shapes according to the groups in that column. Let's try that as an exercise.

# %%
# EXERCISE: vary the marker shape by passing a column name as the `marker` keyword argument

# %% [markdown]
# # Bar Chart
#
# A high-level bar chart is provided by [`bokeh.charts.Bar`]()
#
# For this section, we will use the "autompg" data set. Let's import it and take a quick look:

# %%
from bokeh.sampledata.autompg import autompg
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 6    14.0    8  454.0  220    4354    9.0  70       1
# 7    14.0    8  440.0  215    4312    8.5  70       1
# 8    14.0    8  455.0  225    4425   10.0  70       1
# 9    15.0    8  390.0  190    3850    8.5  70       1
# 10   15.0    8  383.0  170    3563   10.0  70       1
# 11   14.0    8  340.0  160    3609    8.0  70       1
# 12   15.0    8  400.0  150    3761    9.5  70       1
# 13   14.0    8  455.0  225    3086   10.0  70       1
# 14   24.0    4  113.0   95    2372   15.0  70       3
# 15   22.0    6  198.0   95    2833   15.5  70       1
# 16   18.0    6  199.0   97    2774   15.5  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 18   27.0    4   97.0   88    2130   14.5  70       3
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 20   25.0    4  110.0   87    2672   17.5  70       2
# 21   24.0    4  107.0   90    2430   14.5  70       2
# 22   25.0    4  104.0   95    2375   17.5  70       2
# 23   26.0    4  121.0  113    2234   12.5  70       2
# 24   21.0    6  199.0   90    2648   15.0  70       1
# 25   10.0    8  360.0  215    4615   14.0  70       1
# 26   10.0    8  307.0  200    4376   15.0  70       1
# 27   11.0    8  318.0  210    4382   13.5  70       1
# 28    9.0    8  304.0  193    4732   18.5  70       1
# 29   27.0    4   97.0   88    2130   14.5  71       3
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 362  28.0    4  112.0   88    2605   19.6  82       1
# 363  27.0    4  112.0   88    2640   18.6  82       1
# 364  34.0    4  112.0   88    2395   18.0  82       1
# 365  31.0    4  112.0   85    2575   16.2  82       1
# 366  29.0    4  135.0   84    2525   16.0  82       1
# 367  27.0    4  151.0   90    2735   18.0  82       1
# 368  24.0    4  140.0   92    2865   16.4  82       1
# 369  36.0    4  105.0   74    1980   15.3  82       2
# 370  37.0    4   91.0   68    2025   18.2  82       3
# 371  31.0    4   91.0   68    1970   17.6  82       3
# 372  38.0    4  105.0   63    2125   14.7  82       1
# 373  36.0    4   98.0   70    2125   17.3  82       1
# 374  36.0    4  120.0   88    2160   14.5  82       3
# 375  36.0    4  107.0   75    2205   14.5  82       3
# 376  34.0    4  108.0   70    2245   16.9  82       3
# 377  38.0    4   91.0   67    1965   15.0  82       3
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 379  38.0    4   91.0   67    1995   16.2  82       3
# 380  25.0    6  181.0  110    2945   16.4  82       1
# 381  38.0    6  262.0   85    3015   17.0  82       1
# 382  26.0    4  156.0   92    2585   14.5  82       1
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 384  32.0    4  144.0   96    2665   13.9  82       3
# 385  36.0    4  135.0   84    2370   13.0  82       1
# 386  27.0    4  151.0   90    2950   17.3  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                                   name
# 0            chevrolet chevelle malibu
# 1                    buick skylark 320
# 2                   plymouth satellite
# 3                        amc rebel sst
# 4                          ford torino
# 5                     ford galaxie 500
# 6                     chevrolet impala
# 7                    plymouth fury iii
# 8                     pontiac catalina
# 9                   amc ambassador dpl
# 10                 dodge challenger se
# 11                  plymouth 'cuda 340
# 12               chevrolet monte carlo
# 13             buick estate wagon (sw)
# 14               toyota corona mark ii
# 15                     plymouth duster
# 16                          amc hornet
# 17                       ford maverick
# 18                        datsun pl510
# 19        volkswagen 1131 deluxe sedan
# 20                         peugeot 504
# 21                         audi 100 ls
# 22                            saab 99e
# 23                            bmw 2002
# 24                         amc gremlin
# 25                           ford f250
# 26                           chevy c20
# 27                          dodge d200
# 28                            hi 1200d
# 29                        datsun pl510
# ..                                 ...
# 362                 chevrolet cavalier
# 363           chevrolet cavalier wagon
# 364          chevrolet cavalier 2-door
# 365         pontiac j2000 se hatchback
# 366                     dodge aries se
# 367                    pontiac phoenix
# 368               ford fairmont futura
# 369                volkswagen rabbit l
# 370                 mazda glc custom l
# 371                   mazda glc custom
# 372             plymouth horizon miser
# 373                     mercury lynx l
# 374                   nissan stanza xe
# 375                       honda accord
# 376                     toyota corolla
# 377                        honda civic
# 378                 honda civic (auto)
# 379                      datsun 310 gx
# 380              buick century limited
# 381  oldsmobile cutlass ciera (diesel)
# 382         chrysler lebaron medallion
# 383                     ford granada l
# 384                   toyota celica gt
# 385                  dodge charger 2.2
# 386                   chevrolet camaro
# 387                    ford mustang gl
# 388                          vw pickup
# 389                      dodge rampage
# 390                        ford ranger
# 391                         chevy s-10
#
# [392 rows x 9 columns]

# %%
from bokeh.charts import Bar

# %% [markdown]
# A basic bar chart takes the data (again a DataFrame) as the first value, as well as column names for:
#
# * `label` - a column to group to label the x-axis
# * `values` - a column to aggregate values for each group, to give the bar heights
# * `agg` - the name of an aggregation to perform over the values (e.g., `"mean"`, `"max"`, etc.)
#
# A simple example that also specifies some other properties such as `title` and `legend` is shown below:

# %%
p = Bar(autompg, label='cyl', values='mpg', agg='max', 
        title="Max MPG by CYL", legend=None, tools='crosshair')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="42108a60-9093-4e11-b6a8-8a1c547fd52e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("42108a60-9093-4e11-b6a8-8a1c547fd52e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("42108a60-9093-4e11-b6a8-8a1c547fd52e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '42108a60-9093-4e11-b6a8-8a1c547fd52e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6cd639dd-167f-49e9-9f1a-0f96bb481d82":{"roots":{"references":[{"attributes":{"data_source":{"id":"3d6f6c52-8bad-423e-a319-09aafbaec66f","type":"ColumnDataSource"},"glyph":{"id":"387cff12-f253-4577-a14c-dcd07afbdb9f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c7278fd3-83ac-4531-a998-d4f26337117f","type":"GlyphRenderer"},{"attributes":{},"id":"86237b8d-75c6-4fde-8490-a9676f4aba68","type":"BasicTicker"},{"attributes":{"plot":{"id":"3c5c9383-d699-4d3e-8c4a-32ec46a79e5e","subtype":"Chart","type":"Plot"}},"id":"a872b57c-1a17-4416-8bc3-e02b9ce8f013","type":"CrosshairTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a872b57c-1a17-4416-8bc3-e02b9ce8f013","type":"CrosshairTool"}]},"id":"aa6f1596-10a2-47b9-9523-ea66e0372307","type":"Toolbar"},{"attributes":{},"id":"ccc650c5-665c-4d58-aeba-aa08738b79a8","type":"CategoricalTickFormatter"},{"attributes":{},"id":"e66d5b81-3a0b-4dbc-a6dd-c6a05f9bcac8","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e67a032-7471-449c-b419-008d8a5c3158","type":"Rect"},{"attributes":{"data_source":{"id":"793f6a82-2ea6-460c-98af-5a2de74834c8","type":"ColumnDataSource"},"glyph":{"id":"ebdc861f-757f-42a8-b6c4-a4f7632ab4b8","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a874df4a-0ae7-4e66-9cca-085baac294e6","type":"GlyphRenderer"},{"attributes":{},"id":"933bdab4-a6b5-4e2a-96eb-e1d047cbe77f","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"11b8767f-de29-448e-905c-40d1098b811a","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"387cff12-f253-4577-a14c-dcd07afbdb9f","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","color","line_color","x","label","width","line_alpha","fill_alpha","height"],"data":{"chart_index":[{"cyl":6}],"color":["#f22c40"],"cyl":[6],"fill_alpha":[0.8],"height":[38.0],"label":[{"cyl":6}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["6"],"y":[19.0]}},"id":"0f507fb3-e2d0-404c-a05b-b4be3c044c99","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"3c5c9383-d699-4d3e-8c4a-32ec46a79e5e","subtype":"Chart","type":"Plot"},"ticker":{"id":"86237b8d-75c6-4fde-8490-a9676f4aba68","type":"BasicTicker"}},"id":"33c5d6fb-4374-415a-8ef4-8b8bc82201e9","type":"Grid"},{"attributes":{"data_source":{"id":"857a12a3-be70-4b19-9d80-4852b47be41e","type":"ColumnDataSource"},"glyph":{"id":"11b8767f-de29-448e-905c-40d1098b811a","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"733f3914-6e97-43fa-83f4-d607324a766e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","color","line_color","x","label","width","line_alpha","fill_alpha","height"],"data":{"chart_index":[{"cyl":4}],"color":["#f22c40"],"cyl":[4],"fill_alpha":[0.8],"height":[46.6],"label":[{"cyl":4}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["4"],"y":[23.3]}},"id":"857a12a3-be70-4b19-9d80-4852b47be41e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","color","line_color","x","label","width","line_alpha","fill_alpha","height"],"data":{"chart_index":[{"cyl":5}],"color":["#f22c40"],"cyl":[5],"fill_alpha":[0.8],"height":[36.4],"label":[{"cyl":5}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["5"],"y":[18.2]}},"id":"793f6a82-2ea6-460c-98af-5a2de74834c8","type":" ...

# %% [markdown]
# By passing another column name as the `group` parameter, the aggregations can be further subdivided by the groups in that column, and the bars grouped visually. The example below demonstrates this, as well as adding a legend by specifying its location:

# %%
p = Bar(autompg, label='yr', values='mpg', agg='median', group='origin', 
        title="Median MPG by YR, grouped by ORIGIN", legend='top_left', tools='crosshair')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="95e3d2de-b762-412a-b6a5-a0c402ea4ac8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("95e3d2de-b762-412a-b6a5-a0c402ea4ac8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("95e3d2de-b762-412a-b6a5-a0c402ea4ac8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '95e3d2de-b762-412a-b6a5-a0c402ea4ac8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"950e79d7-7fe3-4c2e-bec0-431b48e29ecf":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","color","line_color","x","label","width","line_alpha","fill_alpha","height"],"data":{"chart_index":[{"origin":2,"yr":73}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[24.0],"label":[{"origin":2,"yr":73}],"line_alpha":[1.0],"line_color":["white"],"origin":[2],"width":[0.2],"x":["73:0.75"],"y":[12.0],"yr":[73]}},"id":"2cadacfc-bf53-4a08-b82c-b19a58fabb3e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"0c72381e-e193-4005-86c8-22bba82f4fe3","type":"ColumnDataSource"},"glyph":{"id":"9eb5d2bc-e865-4ad2-b22f-d77ce5b45d2f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"131ab356-2ce3-4099-ac14-c774f205f236","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"cf7c9def-2a31-42a6-8bba-4141b16fdff3","type":"ColumnDataSource"},"glyph":{"id":"53ae2190-7b7e-4333-9fa2-6f133ecd9334","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"bdc4b553-0e31-4341-b3e1-4a595907b4ce","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ef65c5cb-0e07-420d-9fd1-0ae1f23a25ff","type":"Rect"},{"attributes":{},"id":"483a32fe-2fa4-47b5-aefe-8797984a9914","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e776d600-ef4c-4fb3-bcd1-3c0c8d57f5df","type":"Rect"},{"attributes":{"data_source":{"id":"1e021eca-d417-441e-a296-3cea4aa88c6a","type":"ColumnDataSource"},"glyph":{"id":"29770c73-2dfb-4cea-92f3-a5125b475a88","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ce55e010-bfc8-4979-b430-3d90b0081abd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"27d9b596-9707-4c0d-906d-9e8ac04df5cf","type":"ColumnDataSource"},"glyph":{"id":"e7a7d0ab-6c6f-423c-9c1d-e68625f78fcb","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e3e909d0-feb4-4dad-ab80-9a17fb2c9575","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3007536a-f927-4264-a5db-db95be8319e0","type":"ColumnDataSource"},"glyph":{"id":"e8b7372c-763c-4560-a773-05c7a47fad30","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"6325d458-e9d6-4eb5-bff1-77012ac58851","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"511384b9-e790-40c1-a625-c352247dc928","type":"ColumnDataSource"},"glyph":{"id":"79b870bc-b885-4e67-a440-83bcdd08bc7e","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"2653b78b-a8e8-4e7c-acb5-35e3d163936f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7a7d0ab-6c6f-423c-9c1d-e68625f78fcb","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","color","line_color","x","label","width","line_alpha","fill_alpha","height"],"data":{"chart_index":[{"origin":1,"yr":82}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[28.0],"label":[{"origin":1,"yr":82}],"line_alpha":[1.0],"line_color":["white"],"origin":[1],"width":[0.2],"x":["82:0.25"],"y":[14.0],"yr":[82]}},"id":"a6956f25-8b4a-454e-8617-1e34ef84015d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dacf4c4f-4063-47d2-abef-104fa63e6f4e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"heigh ...

# %% [markdown]
# Similarly, bars for subgroups can be stacked visually, by providing a column name for the `stack` parameter. Let's try that as an exercise.

# %%
# EXERCISE: change the chart above to stack the bars with title "Median MPG by YR, stacked by ORIGIN"

# %% [markdown]
# # Histogram
#
# A high-level Histogram is provided by [`bokeh.charts.Histogram`]()
#
# For this section, we will construct our own synthetic data set that has values generated from two different probability distributions.

# %%
import pandas as pd
import numpy as np

# build some distributions
mu, sigma = 0, 0.5
normal = pd.DataFrame({'value': np.random.normal(mu, sigma, 1000), 'type': 'normal'})
lognormal = pd.DataFrame({'value': np.random.lognormal(mu, sigma, 1000), 'type': 'lognormal'})

# create a pandas data frame
#df = pd.append([normal, lognormal])
df = normal.append(lognormal,ignore_index=True)
df[995:1020]
# Out:
#            type     value
# 995      normal -0.067119
# 996      normal  0.414923
# 997      normal -0.264994
# 998      normal  1.303252
# 999      normal  0.209674
# 1000  lognormal  0.690327
# 1001  lognormal  0.376915
# 1002  lognormal  1.142834
# 1003  lognormal  0.532636
# 1004  lognormal  1.081244
# 1005  lognormal  0.665658
# 1006  lognormal  0.952961
# 1007  lognormal  1.037725
# 1008  lognormal  1.473460
# 1009  lognormal  2.187555
# 1010  lognormal  0.809687
# 1011  lognormal  0.634838
# 1012  lognormal  1.916230
# 1013  lognormal  1.575635
# 1014  lognormal  1.364228
# 1015  lognormal  0.724356
# 1016  lognormal  1.444090
# 1017  lognormal  2.368122
# 1018  lognormal  2.295092
# 1019  lognormal  2.002845

# %%
from bokeh.charts import Histogram

# %% [markdown]
# A basic histogram takes the data as the first parameter, and a column name as the `values` parameter. Optionally, you can also specify the number of bins to use by giving a value for the `bins` parameter. The example below shows the distribution of ***all*** the values (both the "normal" and "lognormal" values).

# %%
hist = Histogram(df, values='value', bins=30)
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="46cf2ded-bfed-49ca-a94c-8246f272ed62"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("46cf2ded-bfed-49ca-a94c-8246f272ed62");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("46cf2ded-bfed-49ca-a94c-8246f272ed62");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '46cf2ded-bfed-49ca-a94c-8246f272ed62' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"612fba07-a21c-487d-86a4-f5a1b9323ba1":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"99b74736-c11d-4a04-8553-ad285f7b91c1","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"54b2fe44-e73b-40fc-a4f3-92e16ccd3dbc","type":"Rect"},{"attributes":{},"id":"9214f00c-e20e-44b6-9b16-ad8cec6090ae","type":"LinearScale"},{"attributes":{"data_source":{"id":"7161159d-cd19-4efe-8993-268d0bdbd736","type":"ColumnDataSource"},"glyph":{"id":"223d74a7-3296-4282-bd67-f5e63a951131","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f6e73187-e3bd-492c-9f9d-4ff185275abf","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"e732260f-bf81-4c86-a8e2-8632176bffc4","type":"Title"},{"attributes":{"data_source":{"id":"68110270-b012-4b8f-bbbb-415351a7ac3b","type":"ColumnDataSource"},"glyph":{"id":"ca02e37f-cd6c-4153-b4de-1cda77f63530","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"dd73e845-e0a0-4299-a783-8a3b61e24427","type":"GlyphRenderer"},{"attributes":{},"id":"3fb0dcad-de46-4c53-9457-a3604590706b","type":"BasicTicker"},{"attributes":{"callback":null,"end":281.6},"id":"f067d031-4ba4-4084-9d51-4567f04f145f","type":"Range1d"},{"attributes":{"data_source":{"id":"fda04d80-f7dd-4ff5-be2f-cce87a40799d","type":"ColumnDataSource"},"glyph":{"id":"339511e7-c1d1-4401-8a8f-acc879f03827","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"9a8c87dc-2327-4576-a438-6d5187102b03","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"67d13ef1-edae-4f3a-9d08-95580b471213","type":"Rect"},{"attributes":{"data_source":{"id":"f678903c-9462-4591-9b82-63728f93a3d7","type":"ColumnDataSource"},"glyph":{"id":"632b8d80-1f17-4d0d-86b5-0487545f49d9","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"8d7eeb47-08fe-48f1-96bf-f4ab5f2a7aec","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3ac760cf-ae48-4725-aa58-3f6a0439ec7b","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ec392d1e-7ef3-490c-abbe-84bfc70ebf7f","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","color","line_color","x","label","width","line_alpha","fill_alpha","height"],"data":{"chart_index":["(1.746555, 1.977880]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[44.0],"label":["(1.746555, 1.977880]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.23132533703414726],"x":["1.8622175"],"y":[22.0]}},"id":"303ab05f-7131-42ae-8c3f-1c5fcd795bcc","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"223d74a7-3296-4282-bd67-f5e63a951131","type":"Rect"},{"attributes":{"data_source":{"id":"48ed873b-4863-4d31-a9ec-7ecc0e1fd57f","type":"ColumnDataSource"},"glyph":{"id":"99 ...

# %% [markdown]
# It's also possible to generate multiple histograms at once by grouping the data. The column to group by is specified by the `color` parameter (and the histogram for each group is colored differently automatically). Let's try that as an exercise.

# %%
# EXERCISE: generate histograms for each "type" of distribution, and add a legend to the top left.

# %% [markdown]
# # Box Plot
#
# A high-level box plot is provided by [`bokeh.charts.BoxPlot`]()
#
# For this section we will use the "iris" data set again.

# %%
from bokeh.charts import BoxPlot

# %% [markdown]
# A basic box plot takes the data as the first value, as well as column names for:
#
# * `label` - a column to group to label the x-axis
# * `values` - a column to aggregate values for each group
#
# A simple example that also specifies some other properties such as `title` and `legend` is shown below:

# %%
p = BoxPlot(flowers, label='species', values='petal_width', tools='crosshair', color='#aa4444',
            xlabel='', ylabel='petal width, mm', title='Distributions of petal widths')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="17e9d860-b14e-4ccd-811e-f25770a5cc30"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("17e9d860-b14e-4ccd-811e-f25770a5cc30");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("17e9d860-b14e-4ccd-811e-f25770a5cc30");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '17e9d860-b14e-4ccd-811e-f25770a5cc30' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e1146260-8e5d-4c79-8912-7e104fcef8c8":{"roots":{"references":[{"attributes":{"data_source":{"id":"8465723f-72a7-4b8a-9c8e-96d6bbd0f483","type":"ColumnDataSource"},"glyph":{"id":"2e405b95-8c81-4d6d-9ae3-37af272894e1","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"7c1f4e41-9370-441a-b248-915b0048fc50","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"bc6ebe02-1328-4d2b-a2a2-110745fbb6e6","type":"Segment"},{"attributes":{},"id":"4382227b-ddb6-4d28-85bf-74e02944bee9","type":"CategoricalTicker"},{"attributes":{"below":[{"id":"f37e9c4e-689e-4262-a550-53caafc808c8","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"4d56307a-5366-4bed-8354-c5f4405924d6","type":"LinearAxis"}],"renderers":[{"id":"4d44b925-e283-446f-ac5b-5fcbb291ba70","type":"GlyphRenderer"},{"id":"b3de0b65-c62c-4df1-8bf6-872195781c41","type":"GlyphRenderer"},{"id":"f0ac1ad3-d9f1-4e8b-bcfe-5a9d2dd17aff","type":"GlyphRenderer"},{"id":"19e6ed87-9ab3-4831-9309-3855765098e9","type":"GlyphRenderer"},{"id":"664adb1d-a047-46bd-a7a6-e5e01fea3f29","type":"GlyphRenderer"},{"id":"7c1f4e41-9370-441a-b248-915b0048fc50","type":"GlyphRenderer"},{"id":"91fd3e43-55fa-4ffc-a435-3b07498994db","type":"GlyphRenderer"},{"id":"46578f1b-aa61-45ba-ae6f-2e206a9f53c0","type":"GlyphRenderer"},{"id":"eb93eec4-1c18-4a60-8adc-791240e68a0b","type":"GlyphRenderer"},{"id":"fd8228e9-b232-4bed-98fc-40cb0c3cba26","type":"GlyphRenderer"},{"id":"4e44edcc-01fc-4897-a1ca-ac894cb476b4","type":"Legend"},{"id":"f37e9c4e-689e-4262-a550-53caafc808c8","type":"CategoricalAxis"},{"id":"4d56307a-5366-4bed-8354-c5f4405924d6","type":"LinearAxis"},{"id":"3408af69-b94e-41d3-ade2-83ff991fbfcf","type":"Grid"}],"title":{"id":"1160e5f1-ecb3-4063-92df-d58f1b616cbb","type":"Title"},"tool_events":{"id":"415d9af4-1a89-4b55-abb0-4ebaaebf15ca","type":"ToolEvents"},"toolbar":{"id":"9a25ae75-223a-425d-8ca8-97b85a3abd29","type":"Toolbar"},"x_range":{"id":"b980bafe-9d1a-4f4a-8c4a-4e84cf2ef995","type":"FactorRange"},"x_scale":{"id":"dd8ce0eb-cf0e-4122-8857-ce81cccad594","type":"CategoricalScale"},"y_range":{"id":"ea2801eb-013e-442c-ac33-ffb6d043e93e","type":"Range1d"},"y_scale":{"id":"e4426c56-e24c-4f0f-bd97-e0f5626ebfb5","type":"LinearScale"}},"id":"46bfa77f-8c07-4b97-ba66-10b35e212c54","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","color","line_color","x","label","width","line_alpha","fill_alpha","height"],"data":{"chart_index":[{"species":"setosa"}],"color":["#aa4444"],"fill_alpha":[0.8],"height":[0.0],"label":[{"species":"setosa"}],"line_alpha":[1.0],"line_color":["black"],"species":["setosa"],"width":[0.8],"x":["setosa"],"y":[0.2]}},"id":"961b7063-3bf4-49b8-9faa-ed1233686c96","type":"ColumnDataSource"},{"attributes":{},"id":"dd8ce0eb-cf0e-4122-8857-ce81cccad594","type":"CategoricalScale"},{"attributes":{},"id":"584490cf-5f97-4dc7-bf5e-cea399939ff2","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"versicolor"},"renderers":[{"id":"664adb1d-a047-46bd-a7a6-e5e01fea3f29","type":"GlyphRenderer"},{"id":"7c1f4e41-9370-441a-b248-915b0048fc50","type":"GlyphRenderer"},{"id":"91fd3e43-55fa-4ffc-a435-3b07498994db","type":"GlyphRenderer"}]},"id":"232c16a8-948e-494b-b306-fc1557cd4204","type":"LegendItem"},{"attributes":{"data_source":{"id":"14faade9-e910-4855-93bf-fd3c4b6a293e","type":"ColumnDataSource"},"glyph":{"id":"b82909ea-f04f-4d51-9de6-c3037e9a3ec5","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"46578f1b-aa61-45ba-ae6f-2e206a9f53c0","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7cad366b-9c0f-47ca-9d3f-eff6c3e0332f","type":"Rect"},{"attributes":{"label":{"value":"setosa"},"renderers":[{"id":"4d44b925-e283- ...

# %% [markdown]
# Instead of a single color, the box and whiskers groups can be colored by grouping one of the columns. This is done by passing a column name as the `color` parameter. Let's try that as an exercise.

# %%
# EXERCISE: color the boxes by "species" and add a legend to the top left

# %% [markdown]
# ---
#
# # Further reading

# %% [markdown]
# http://nbviewer.jupyter.org/github/bokeh/bokeh/tree/0.11.1/examples/charts/file/
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh/tree/0.11.1/examples/howto/charts/
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh-demos/blob/master/presentations/2016-03-pydata-strata/notebooks/Charts.ipynb
#
# http://nbviewer.jupyter.org/github/bokeh/bokeh-demos/blob/master/presentations/2016-03-pydata-strata/notebooks/Charts%20Demo.ipynb

# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>08. Annotations</h2></div>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="783480b0-9f1c-4175-9793-d94ea7c2293c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Overview
#
# Sometimes we want to add visual cues (boundary lines, shaded regions, labels and arrows, etc.) to our plots to call out some feature or other. Bokeh has several annotation types available for uses like this. Typically to add annotations we create the "low level" annotation object directly, and add it to our `Plot`, `Figure` or `Chart` using `add_layout`. Let's take a look at some specific examples.

# %% [markdown]
# ## Spans
#
# `Spans` are "infinite" vertical or horizonal lines. When creating them, you specify the `dimension` that should be spanned (i.e., `width` or `height`), any visual line properties for the appearance, and the location along the dimension where the line should be drawn. Let's look at an example that adds two horizontal spans to a simple plot:

# %%
import numpy as np
from bokeh.models.annotations import Span

x = np.linspace(0, 20, 200)
y = np.sin(x)

p = figure(y_range=(-2, 2))
p.line(x, y)

upper = Span(location=1, dimension='width', line_color='olive', line_width=4)
p.add_layout(upper)

lower = Span(location=-1, dimension='width', line_color='firebrick', line_width=4)
p.add_layout(lower)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="362216cc-8739-4fda-a10e-7e763bf4bc63"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("362216cc-8739-4fda-a10e-7e763bf4bc63");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("362216cc-8739-4fda-a10e-7e763bf4bc63");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '362216cc-8739-4fda-a10e-7e763bf4bc63' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2a75f533-4a13-4fbb-b8ce-b37f39f1376b":{"roots":{"references":[{"attributes":{"plot":{"id":"39373347-9d1e-46be-b39b-18c63d2931c4","subtype":"Figure","type":"Plot"}},"id":"658e4d73-31d5-477b-8c81-9e7436a0664e","type":"HelpTool"},{"attributes":{},"id":"a0b62e82-5e67-4757-9120-abbc5bd021b4","type":"BasicTicker"},{"attributes":{"callback":null,"end":2,"start":-2},"id":"17c4763d-7176-4851-9be5-f59863201440","type":"Range1d"},{"attributes":{"plot":{"id":"39373347-9d1e-46be-b39b-18c63d2931c4","subtype":"Figure","type":"Plot"}},"id":"a57aaec4-ec54-434d-bd1c-cf63dc794b4b","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7ff1c917-297a-40ab-82dc-d0ff44fb4098","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"ae6221e0-d7f8-4ebe-89e8-236966ac7133","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"18fa3cd7-0c62-4353-a9ed-9b890ccbb940","type":"Line"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6ac3b616-ea1b-412d-839f-460818882a7d","type":"PanTool"},{"id":"f80407cd-15f6-4112-b4a6-27dc694adcf0","type":"WheelZoomTool"},{"id":"dbd0fba9-8e62-455b-bde4-c47dbd4ea311","type":"BoxZoomTool"},{"id":"d4d8ef69-df8a-4d2a-a6f8-61a53fc71576","type":"SaveTool"},{"id":"a57aaec4-ec54-434d-bd1c-cf63dc794b4b","type":"ResetTool"},{"id":"658e4d73-31d5-477b-8c81-9e7436a0664e","type":"HelpTool"}]},"id":"b2d97d26-b192-4c6f-a279-3da5990eacac","type":"Toolbar"},{"attributes":{"plot":{"id":"39373347-9d1e-46be-b39b-18c63d2931c4","subtype":"Figure","type":"Plot"}},"id":"f80407cd-15f6-4112-b4a6-27dc694adcf0","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"39373347-9d1e-46be-b39b-18c63d2931c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"cf8c329c-04a3-46cc-bcd9-bb046aa249cc","type":"BasicTicker"}},"id":"181ea114-158b-4663-ab18-2ac216af4f6d","type":"Grid"},{"attributes":{},"id":"cf8c329c-04a3-46cc-bcd9-bb046aa249cc","type":"BasicTicker"},{"attributes":{},"id":"7ce822c9-8d8e-4c5e-a75e-ce874328a9bd","type":"ToolEvents"},{"attributes":{"below":[{"id":"df49cacb-d7aa-4861-8256-b701d934824f","type":"LinearAxis"}],"left":[{"id":"01fe8c95-cd92-4de0-aefb-a4cd0d3824d0","type":"LinearAxis"}],"renderers":[{"id":"df49cacb-d7aa-4861-8256-b701d934824f","type":"LinearAxis"},{"id":"1dc380b5-86e1-448d-a28c-6392fe884e96","type":"Grid"},{"id":"01fe8c95-cd92-4de0-aefb-a4cd0d3824d0","type":"LinearAxis"},{"id":"181ea114-158b-4663-ab18-2ac216af4f6d","type":"Grid"},{"id":"7ff1c917-297a-40ab-82dc-d0ff44fb4098","type":"BoxAnnotation"},{"id":"baad60ee-7c85-44a1-afa7-1a7609c0412f","type":"GlyphRenderer"},{"id":"937ee093-74ef-431f-aff9-fc98a6930a0a","type":"Span"},{"id":"30e13d42-4aa2-4875-8788-6af5037fa688","type":"Span"}],"title":{"id":"f094a652-5195-4a8f-b16b-628b990580bf","type":"Title"},"tool_events":{"id":"7ce822c9-8d8e-4c5e-a75e-ce874328a9bd","type":"ToolEvents"},"toolbar":{"id":"b2d97d26-b192-4c6f-a279-3da5990eacac","type":"Toolbar"},"x_range":{"id":"ae6221e0-d7f8-4ebe-89e8-236966ac7133","type":"DataRange1d"},"x_scale":{"id":"782d4b96-6bc6-4c83-bbbe-4b5e5f8861c1","type":"LinearScale"},"y_range":{"id":"17c4763d-7176-4851-9be5-f59863201440","type":"Range1d"},"y_scale":{"id":"6a2c1e83-9ff0-4efc-996e-8337ae089b58","type":"LinearScale"}},"id":"39373347-9d1e-46be-b39b-18c63d2931c4","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"18aff3b5-febc-462d-839d-0d75f4b2a848","type":"BasicTickFormatter"},"plot":{"id":"39373347-9d1e-46be-b39b-18c63d2931c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"a0b62e82-5e67-4757-9120-abbc5bd021b4","type":"BasicTicker"}},"id":"df49cacb-d7aa-4861-8256-b701d9348 ...

# %% [markdown]
# ## Box Annotations
#
# Sometimes you might want to call out some region of the plot by drawing a shaded box. This can be done with the `BoxAnnotation`, which is configured with the coordinate properties:
# * `top`
# * `left`
# * `bottom`
# * `right`
#
# as well as any visual line or fill properties to control the appearance.
#
# "Infinite" boxes can be made by leaving any of the coordinates unspecified. E.g., if `top` is not given, the box will always extend to the top of the plot area, regardless of any panning or zooming that happens.
#
# Let's take a look at an example that adds a few shaded boxes to a plot:

# %%
import numpy as np
from bokeh.models.annotations import BoxAnnotation

x = np.linspace(0, 20, 200)
y = np.sin(x)

p = figure(y_range=(-2, 2))
p.line(x, y)

# region that always fills the top of the plot
upper = BoxAnnotation(bottom=1, fill_alpha=0.6, fill_color='olive')
p.add_layout(upper)

# region that always fills the bottom of the plot
lower = BoxAnnotation(top=-1, fill_alpha=0.1, fill_color='firebrick')
p.add_layout(lower)

# a finite region
center = BoxAnnotation(top=0.6, bottom=-0.3, left=7, right=12, fill_alpha=0.1, fill_color='navy')
p.add_layout(center)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6ba39335-4f6c-4095-825b-7483debd1820"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6ba39335-4f6c-4095-825b-7483debd1820");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6ba39335-4f6c-4095-825b-7483debd1820");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6ba39335-4f6c-4095-825b-7483debd1820' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"15f80b91-0e26-4ba4-b654-433b4429ce76":{"roots":{"references":[{"attributes":{},"id":"0da16b55-a0b5-4370-b793-636da45bf2d3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3868b722-d704-4bb7-907d-231f1e99845e","subtype":"Figure","type":"Plot"}},"id":"c0ed3df0-c28c-4b49-9a86-3a9cfc0ece8c","type":"HelpTool"},{"attributes":{"formatter":{"id":"0da16b55-a0b5-4370-b793-636da45bf2d3","type":"BasicTickFormatter"},"plot":{"id":"3868b722-d704-4bb7-907d-231f1e99845e","subtype":"Figure","type":"Plot"},"ticker":{"id":"9fdd89b8-9f88-4341-ae92-8ea0a98c5d4e","type":"BasicTicker"}},"id":"0f905180-71c3-4802-a497-d4f944a1b080","type":"LinearAxis"},{"attributes":{},"id":"e3c58920-b5a1-40cc-8625-ba4794dcec2a","type":"BasicTicker"},{"attributes":{"bottom":-0.3,"fill_alpha":{"value":0.1},"fill_color":{"value":"navy"},"left":7,"plot":{"id":"3868b722-d704-4bb7-907d-231f1e99845e","subtype":"Figure","type":"Plot"},"right":12,"top":0.6},"id":"61a01598-fe64-482d-a060-f93367330fb1","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"3868b722-d704-4bb7-907d-231f1e99845e","subtype":"Figure","type":"Plot"}},"id":"8897ca3a-0597-4d72-bab1-78cc6fa1af1a","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a420b4d5-7f3f-474a-b27d-20dd879cd6b9","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"01f6db77-c6cb-4885-8bbf-619ea44e2895","type":"PanTool"},{"id":"87d9874b-f00d-4e09-b3eb-08b33257046e","type":"WheelZoomTool"},{"id":"588a3615-e830-4df3-9641-63bfb80a5318","type":"BoxZoomTool"},{"id":"b36bdde2-fc5a-4a39-a45d-d2f0376eb648","type":"SaveTool"},{"id":"8897ca3a-0597-4d72-bab1-78cc6fa1af1a","type":"ResetTool"},{"id":"c0ed3df0-c28c-4b49-9a86-3a9cfc0ece8c","type":"HelpTool"}]},"id":"c1f08c2c-915c-462b-a88f-74127018f086","type":"Toolbar"},{"attributes":{"data_source":{"id":"87bce9be-94ac-4003-a47e-28fe5ff7bf24","type":"ColumnDataSource"},"glyph":{"id":"c1f2a16a-28df-4bc2-87fc-1288566069b2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1cf2b68e-edea-4785-bcbd-24ecf3c2fe7b","type":"Line"},"selection_glyph":null},"id":"2d36a5a4-91c8-4295-b638-6fdd36a1d41d","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1f2a16a-28df-4bc2-87fc-1288566069b2","type":"Line"},{"attributes":{},"id":"c1282c71-c47e-474a-8105-aa32fc3f38ff","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"3868b722-d704-4bb7-907d-231f1e99845e","subtype":"Figure","type":"Plot"},"ticker":{"id":"e3c58920-b5a1-40cc-8625-ba4794dcec2a","type":"BasicTicker"}},"id":"88a7780b-7901-43b7-a22f-631dd47fd26f","type":"Grid"},{"attributes":{},"id":"a8047e9f-74c2-45ba-b736-85c0d5b88ad5","type":"LinearScale"},{"attributes":{"callback":null},"id":"7817f19e-1858-4569-bd5b-1341f4df3814","type":"DataRange1d"},{"attributes":{},"id":"fabc810f-85d2-4405-9cfb-9cc37f093b67","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3868b722-d704-4bb7-907d-231f1e99845e","subtype":"Figure","type":"Plot"}},"id":"87d9874b-f00d-4e09-b3eb-08b33257046e","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"fabc810f-85d2-4405-9cfb-9cc37f093b67","type":"BasicTickFormatter"},"plot":{"id":"3868b722-d704-4bb7-907d-231f1e99845e","subtype":"Figure","type":"Plot"},"ticker":{"id":"e3c58920-b5a1-40cc-8625-ba4794dcec2a","type":"BasicTicker"}},"id":"dfb12b6f-2165-4fdc-9d81-36d22764d707","type":"LinearAxis"},{"attributes":{},"id":"04a5ffd3-60c4-43b3-9bd4-0791619d24f7","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__ ...

# %% [markdown]
# ## Label
#
# The `Label` annotation allows you to easily attach single text labels to plots. The position and text to display are configured as `x`, `y`, and `text`:
#
# ```python
# Label(x=10, y=5, text="Some Label")
# ```
#
# By default the units are in "data space" but `x_units` and `y_units` maybe set to `"screen"` to position the label relative to the canvas. Labels can also accept `x_offset` and `y_offset` to offset the final position from `x` and `y` by a given screen space distance.
#
# `Label` objects also have standard text, line (`border_line`) and fill (`background_fill`) properties. The line and fill properties apply to a bounding box around the text:
#
# ```python
# Label(x=10, y=5, text="Some Label", text_font_size="12pt",
#       border_line_color="red", background_fill_color="blue")
# ```

# %%
from bokeh.models.annotations import Label
from bokeh.plotting import figure

p = figure(x_range=(0,10), y_range=(0,10))
p.circle([2, 5, 8], [4, 7, 6], color="olive", size=10)

label = Label(x=5, y=7, x_offset=12, text="Second Point", text_baseline="middle")
p.add_layout(label)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="335c9fc5-9759-40a7-a528-6fdf654a4f8e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("335c9fc5-9759-40a7-a528-6fdf654a4f8e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("335c9fc5-9759-40a7-a528-6fdf654a4f8e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '335c9fc5-9759-40a7-a528-6fdf654a4f8e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"23f30f21-b666-49d6-8b6f-600da6b9bddc":{"roots":{"references":[{"attributes":{"formatter":{"id":"64e3e911-e8c2-4ded-b7df-affdf5fec483","type":"BasicTickFormatter"},"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"},"ticker":{"id":"70217853-a60b-4ab3-88c1-9ac58e74e645","type":"BasicTicker"}},"id":"6e8f304b-d02b-4be8-8a42-9d43a70752c5","type":"LinearAxis"},{"attributes":{"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"}},"id":"aac6c7fa-b024-439f-bbea-3481a90399a6","type":"PanTool"},{"attributes":{"overlay":{"id":"510ca5c1-e210-465c-84f0-4695d8b49eff","type":"BoxAnnotation"},"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"}},"id":"4e7a9690-007c-4460-a1d2-61b7ef614295","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"},"text":"Second Point","text_baseline":"middle","x":5,"x_offset":12,"y":7},"id":"6619eaf4-afe3-4648-b01a-f51549640d7b","type":"Label"},{"attributes":{"below":[{"id":"9bbf653c-9b7e-4885-8e5b-3d4502fcd36d","type":"LinearAxis"}],"left":[{"id":"6e8f304b-d02b-4be8-8a42-9d43a70752c5","type":"LinearAxis"}],"renderers":[{"id":"9bbf653c-9b7e-4885-8e5b-3d4502fcd36d","type":"LinearAxis"},{"id":"3b0616d5-00dd-4bb9-a2c6-1fa1aa4adfe7","type":"Grid"},{"id":"6e8f304b-d02b-4be8-8a42-9d43a70752c5","type":"LinearAxis"},{"id":"98b8f722-6992-4c9e-b5c8-4f27d00ec33e","type":"Grid"},{"id":"510ca5c1-e210-465c-84f0-4695d8b49eff","type":"BoxAnnotation"},{"id":"d06f5bd1-767b-40ae-9506-9e4813c1ba06","type":"GlyphRenderer"},{"id":"6619eaf4-afe3-4648-b01a-f51549640d7b","type":"Label"}],"title":{"id":"3e8db632-c851-495f-a49e-870506f8363a","type":"Title"},"tool_events":{"id":"4379d491-7bce-4b78-8e22-1516c37eec14","type":"ToolEvents"},"toolbar":{"id":"c0a0274f-b535-47a8-9607-5333cef92f53","type":"Toolbar"},"x_range":{"id":"62b82609-0982-4e02-91d5-ecc177d97706","type":"Range1d"},"x_scale":{"id":"a1856821-6d45-4123-b318-348802a3fba8","type":"LinearScale"},"y_range":{"id":"803a0408-63d4-48ae-bc70-4d69e52e32ee","type":"Range1d"},"y_scale":{"id":"4e95c67e-d21e-40b6-a80f-422aaef923ef","type":"LinearScale"}},"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":10},"id":"803a0408-63d4-48ae-bc70-4d69e52e32ee","type":"Range1d"},{"attributes":{"formatter":{"id":"b60500ae-c4e0-4766-bd2b-5e973a66f332","type":"BasicTickFormatter"},"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"},"ticker":{"id":"e907ccbe-c564-406e-a8e2-3852ebfcc372","type":"BasicTicker"}},"id":"9bbf653c-9b7e-4885-8e5b-3d4502fcd36d","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"c611ade3-24e3-4732-9fb7-d133f53d0993","type":"Circle"},{"attributes":{},"id":"b60500ae-c4e0-4766-bd2b-5e973a66f332","type":"BasicTickFormatter"},{"attributes":{},"id":"e907ccbe-c564-406e-a8e2-3852ebfcc372","type":"BasicTicker"},{"attributes":{},"id":"4379d491-7bce-4b78-8e22-1516c37eec14","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"},"ticker":{"id":"70217853-a60b-4ab3-88c1-9ac58e74e645","type":"BasicTicker"}},"id":"98b8f722-6992-4c9e-b5c8-4f27d00ec33e","type":"Grid"},{"attributes":{"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"Plot"},"ticker":{"id":"e907ccbe-c564-406e-a8e2-3852ebfcc372","type":"BasicTicker"}},"id":"3b0616d5-00dd-4bb9-a2c6-1fa1aa4adfe7","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[2,5,8],"y":[4,7,6]}},"id":"6681718d-6b32-4cfa-8478-55483ca05d0a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5d15898e-bdd6-49ff-a8d0-46e3952d3844","subtype":"Figure","type":"P ...

# %%
# EXERCISE: experiment with Label

# %% [markdown]
# ## LabelSet
#
# The `LabelSet` annotation allows you to create many labels at once, for instance if you want to label an entire set of scatter markers. They are similar to `Label`, but they can also
# accept a `ColumnDataSource` as the `source` property, and then `x` and `y` may refer to columns in the data source, e.g. `x="col2"` (but may also still be fixed values, e.g. `x=10`).

# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, LabelSet


source = ColumnDataSource(data=dict(
    temp=[166, 171, 172, 168, 174, 162],
    pressure=[165, 189, 220, 141, 260, 174],
    names=['A', 'B', 'C', 'D', 'E', 'F']))

p = figure(x_range=(160, 175))
p.scatter(x='temp', y='pressure', size=8, source=source)
p.xaxis.axis_label = 'Temperature (C)'
p.yaxis.axis_label = 'Pressure (lbs)'

labels = LabelSet(x='temp', y='pressure', text='names', level='glyph',
                  x_offset=15, y_offset=15, source=source, render_mode='canvas')


p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3f6b8b5a-b154-4c07-a56e-c73b828ed052"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3f6b8b5a-b154-4c07-a56e-c73b828ed052");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3f6b8b5a-b154-4c07-a56e-c73b828ed052");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3f6b8b5a-b154-4c07-a56e-c73b828ed052' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"411f0145-ff0a-4585-903f-afe0eafca646":{"roots":{"references":[{"attributes":{"data_source":{"id":"8c42ad60-6ddb-4e04-a041-6f6950c08548","type":"ColumnDataSource"},"glyph":{"id":"49110fc0-72e4-497f-8df3-4de12e899600","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"42a4ee12-af38-4eb1-9be1-53b1be555a05","type":"Circle"},"selection_glyph":null},"id":"e411fb8a-9b37-4dbf-a915-81cf53525e05","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"387d377d-0606-4d38-a9b4-7ff51884578c","type":"LinearAxis"}],"left":[{"id":"7c8af008-3c51-4757-a135-178782232665","type":"LinearAxis"}],"renderers":[{"id":"387d377d-0606-4d38-a9b4-7ff51884578c","type":"LinearAxis"},{"id":"127fce51-e610-4e23-ab51-e53f8ab4cc17","type":"Grid"},{"id":"7c8af008-3c51-4757-a135-178782232665","type":"LinearAxis"},{"id":"9f1a8e45-cc25-49d1-bbe7-2ebc48a10d60","type":"Grid"},{"id":"5e8d6f77-6808-4402-8330-1abcda54fce2","type":"BoxAnnotation"},{"id":"e411fb8a-9b37-4dbf-a915-81cf53525e05","type":"GlyphRenderer"},{"id":"0d35c84b-674c-45f1-84b7-5ba7d3398904","type":"LabelSet"}],"title":{"id":"37c245bf-2bfd-419b-b54b-654ff82cd33c","type":"Title"},"tool_events":{"id":"45dafd39-ae26-47c1-b9ad-6485ecebd224","type":"ToolEvents"},"toolbar":{"id":"d909978a-8b0b-457d-823d-00f3e9a7b1e4","type":"Toolbar"},"x_range":{"id":"336df671-75e6-4e1d-a890-2bc818dafe94","type":"Range1d"},"x_scale":{"id":"6d24e8c0-7304-4a53-b439-f280531bfb6b","type":"LinearScale"},"y_range":{"id":"77443e25-d77f-4c63-be6f-e3784620778f","type":"DataRange1d"},"y_scale":{"id":"aa5b06f4-7ae2-4fdd-9e9a-c17fd1b9c594","type":"LinearScale"}},"id":"053c9f05-aeb8-4c23-be11-306ed7ea6e5c","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"053c9f05-aeb8-4c23-be11-306ed7ea6e5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"8d46bed6-8254-49a9-ae08-3a31f8c6736f","type":"BasicTicker"}},"id":"9f1a8e45-cc25-49d1-bbe7-2ebc48a10d60","type":"Grid"},{"attributes":{},"id":"c5674759-808d-4117-9c31-a0a496aa4fef","type":"BasicTicker"},{"attributes":{"axis_label":"Temperature (C)","formatter":{"id":"25376ab0-a3cd-4263-a210-f746af2cf7e3","type":"BasicTickFormatter"},"plot":{"id":"053c9f05-aeb8-4c23-be11-306ed7ea6e5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"c5674759-808d-4117-9c31-a0a496aa4fef","type":"BasicTicker"}},"id":"387d377d-0606-4d38-a9b4-7ff51884578c","type":"LinearAxis"},{"attributes":{"overlay":{"id":"5e8d6f77-6808-4402-8330-1abcda54fce2","type":"BoxAnnotation"},"plot":{"id":"053c9f05-aeb8-4c23-be11-306ed7ea6e5c","subtype":"Figure","type":"Plot"}},"id":"49bc7c9c-447b-4ae0-bead-b066fe6e577b","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["pressure","names","temp"],"data":{"names":["A","B","C","D","E","F"],"pressure":[165,189,220,141,260,174],"temp":[166,171,172,168,174,162]}},"id":"8c42ad60-6ddb-4e04-a041-6f6950c08548","type":"ColumnDataSource"},{"attributes":{"level":"glyph","plot":{"id":"053c9f05-aeb8-4c23-be11-306ed7ea6e5c","subtype":"Figure","type":"Plot"},"source":{"id":"8c42ad60-6ddb-4e04-a041-6f6950c08548","type":"ColumnDataSource"},"text":{"field":"names"},"x":{"field":"temp"},"x_offset":{"value":15},"y":{"field":"pressure"},"y_offset":{"value":15}},"id":"0d35c84b-674c-45f1-84b7-5ba7d3398904","type":"LabelSet"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"temp"},"y":{"field":"pressure"}},"id":"42a4ee12-af38-4eb1-9be1-53b1be555a05","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"37c245bf-2bfd-419b-b54b-654ff82cd33c","type":"Title"},{"attributes":{"callback":null},"id":"77443e25-d77f-4c63-be6f-e3784620778f","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"db1a8795-503e-45f9-92cd-b88e82e969f5","type":"PanTool"},{"id":"e22050d8-c6a4-4f69-aeca-9780ac1b929a","type":"W ...

# %%
# EXERCISE: experiment with LabelSet

# %% [markdown]
# ## Arrows
#
# The `Arrow` annotation allows you to "point" at different things on your plot, and can be especially useful in conjuction with labels.
#
# For example, to create an arrow that points from `(0,0)` to `(1,1)`:
#
# ```python
# p.add_layout(Arrow(x_start=0, y_start=0, x_end=1, y_end=0))
# ```
#
# This arrow will have the default [`OpenHead`](http://bokeh.pydata.org/en/latest/docs/reference/models/arrow_heads.html#bokeh.models.arrow_heads.OpenHead) arrow head at the end of the arrow. Other kinds of arrow heads include [`NormalHead`](http://bokeh.pydata.org/en/latest/docs/reference/models/arrow_heads.html#bokeh.models.arrow_heads.NormalHead) and [`VeeHead`](http://bokeh.pydata.org/en/latest/docs/reference/models/arrow_heads.html#bokeh.models.arrow_heads.VeeHead). The arrow head type can be controlled by setting the `start` and `end` properties of `Arrow` objects:
#
# ```python
# p.add_layout(Arrow(start=OpenHead(), end=VeeHead(),
#              x_start=0, y_start=0, x_end=1, y_end=0))
# ```
#
# This will create a double-ended arrow with an "open" head at the start, and a "vee" head at the end. Arrowheads have the standard set of line and fill properties to control their appearance. As an example
#
# ```python
# OpenHead(line_color="firebrick", line_width=4)
# ```
#
# The code and plot below shows several of these configurations together.

# %%
from bokeh.models.annotations import Arrow
from bokeh.models.arrow_heads import OpenHead, NormalHead, VeeHead

p = figure(plot_width=600, plot_height=600)

p.circle(x=[0, 1, 0.5], y=[0, 0, 0.7], radius=0.1,
         color=["navy", "yellow", "red"], fill_alpha=0.1)

p.add_layout(Arrow(end=OpenHead(line_color="firebrick", line_width=4),
                   x_start=0, y_start=0, x_end=1, y_end=0))

p.add_layout(Arrow(end=NormalHead(fill_color="orange"),
                   x_start=1, y_start=0, x_end=0.5, y_end=0.7))

p.add_layout(Arrow(end=VeeHead(size=35), line_color="red",
                   x_start=0.5, y_start=0.7, x_end=0, y_end=0))

show(p)
import bokeh
help(bokeh.models.arrow_heads.VeeHead)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="01df99ca-4042-4988-8e3a-39b53a43c706"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("01df99ca-4042-4988-8e3a-39b53a43c706");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01df99ca-4042-4988-8e3a-39b53a43c706");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01df99ca-4042-4988-8e3a-39b53a43c706' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"449e5df2-bb6b-4808-abe8-abc4bb194249":{"roots":{"references":[{"attributes":{},"id":"954c09bc-04b2-49a8-8dd5-fd367c82db7e","type":"LinearScale"},{"attributes":{"callback":null},"id":"51b078fb-77c3-48f6-9f1d-8fb3dc7b4e8c","type":"DataRange1d"},{"attributes":{"callback":null},"id":"47d9b7b2-9b07-4fee-a843-4ef3f32d0bb1","type":"DataRange1d"},{"attributes":{"below":[{"id":"8333f216-ef64-4d5b-8d2b-713325de4dc5","type":"LinearAxis"}],"left":[{"id":"5fbd97c2-96d4-4f33-a309-dc70c379aaf0","type":"LinearAxis"}],"renderers":[{"id":"8333f216-ef64-4d5b-8d2b-713325de4dc5","type":"LinearAxis"},{"id":"131aadbb-6ccf-4891-b39a-d464045d71cb","type":"Grid"},{"id":"5fbd97c2-96d4-4f33-a309-dc70c379aaf0","type":"LinearAxis"},{"id":"f2ab6111-939f-4eb6-8fa9-43924c0b06f6","type":"Grid"},{"id":"a71e662f-1e2c-4867-9183-7b3be37495a0","type":"BoxAnnotation"},{"id":"583370ab-5646-458b-bf47-27d5bb9081b0","type":"GlyphRenderer"},{"id":"f55fb520-adb5-4fc3-91b5-c9c762329bcf","type":"Arrow"},{"id":"b3e49a15-5d77-4306-afa0-edd306af859d","type":"Arrow"},{"id":"9299e98a-6535-4a66-9f49-28a3a878174d","type":"Arrow"}],"title":{"id":"d2597d31-7135-4e45-bb19-d0b552029295","type":"Title"},"tool_events":{"id":"176be553-13c9-46e2-9825-7eda3110d021","type":"ToolEvents"},"toolbar":{"id":"6155709d-15ee-4c8e-ab93-5a391fc659b9","type":"Toolbar"},"x_range":{"id":"51b078fb-77c3-48f6-9f1d-8fb3dc7b4e8c","type":"DataRange1d"},"x_scale":{"id":"27e0f33d-fde7-4668-8d11-a3711faa1e7d","type":"LinearScale"},"y_range":{"id":"47d9b7b2-9b07-4fee-a843-4ef3f32d0bb1","type":"DataRange1d"},"y_scale":{"id":"954c09bc-04b2-49a8-8dd5-fd367c82db7e","type":"LinearScale"}},"id":"98960ead-7a1a-4482-a6d3-6e6bf7f9268b","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a71e662f-1e2c-4867-9183-7b3be37495a0","type":"BoxAnnotation"},{"attributes":{},"id":"8942d2fe-f73b-4023-91bc-116701239dbe","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"orange"},"plot":null},"id":"f6ba6ad7-90ed-40f7-9572-d94da06b45be","type":"NormalHead"},{"attributes":{"line_color":{"value":"firebrick"},"line_width":{"value":4},"plot":null},"id":"aa74ae93-77fe-4357-9215-e5a7137703f2","type":"OpenHead"},{"attributes":{},"id":"c6bc18ce-8ac8-4218-9fab-64c46b54ecd4","type":"BasicTicker"},{"attributes":{"plot":{"id":"98960ead-7a1a-4482-a6d3-6e6bf7f9268b","subtype":"Figure","type":"Plot"}},"id":"03098ef1-4611-4c7e-905f-cb4d9d0d8a3f","type":"PanTool"},{"attributes":{},"id":"27e0f33d-fde7-4668-8d11-a3711faa1e7d","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y","fill_color","line_color"],"data":{"fill_color":["navy","yellow","red"],"line_color":["navy","yellow","red"],"x":[0,1,0.5],"y":[0,0,0.7]}},"id":"a5936468-171c-4fd1-8ca4-890c2a426da4","type":"ColumnDataSource"},{"attributes":{},"id":"66318fbe-4d4e-4e94-8ec7-8141c42092cf","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"d2597d31-7135-4e45-bb19-d0b552029295","type":"Title"},{"attributes":{},"id":"176be553-13c9-46e2-9825-7eda3110d021","type":"ToolEvents"},{"attributes":{"data_source":{"id":"a5936468-171c-4fd1-8ca4-890c2a426da4","type":"ColumnDataSource"},"glyph":{"id":"1144242b-92a8-48af-a879-18c5cec018cf","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1172113d-5b01-4e16-84ee-0d7e9a9b1a4d","type":"Circle"},"selection_glyph":null},"id":"583370ab-5646-458b-bf47-27d5bb9081b0","type":"GlyphRenderer"},{"attributes":{"plot":null,"size":35},"id":"f3c1a047-4cad-4827-b829-fed3558bb1cf","type":"VeeHead"},{"attributes":{"overlay":{"id":"a71e662f-1e2c-4867-9183-7b3be37495a0","type":"BoxAnnotation"},"plot":{"id":"98960ead-7a1a-4482-a6d3-6e6bf7f9268b","subtype":"Figure","type": ...
# Help on class VeeHead in module bokeh.models.arrow_heads:
#
# class VeeHead(ArrowHead)
#  |  Render a vee-style arrow head.
#  |
#  |  Method resolution order:
#  |      VeeHead
#  |      ArrowHead
#  |      bokeh.models.annotations.Annotation
#  |      bokeh.models.renderers.Renderer
#  |      bokeh.model.Model
#  |      bokeh.core.has_props.HasProps
#  |      bokeh.util.callback_manager.PropertyCallbackManager
#  |      bokeh.util.callback_manager.EventCallbackManager
#  |      builtins.object
#  |
#  |  Data descriptors defined here:
#  |
#  |  fill_alpha
#  |      The fill alpha values for the arrow head interior.
#  |
#  |  fill_color
#  |      The fill color values for the arrow head interior.
#  |
#  |  line_alpha
#  |      The line alpha values for the arrow head outline.
#  |
#  |  line_cap
#  |      The line cap values for the arrow head outline.
#  |
#  |  line_color
#  |      The line color values for the arrow head outline.
#  |
#  |  line_dash
#  |      The line dash values for the arrow head outline.
#  |
#  |  line_dash_offset
#  |      The line dash offset values for the arrow head outline.
#  |
#  |  line_join
#  |      The line join values for the arrow head outline.
#  |
#  |  line_width
#  |      The line width values for the arrow head outline.
#  |
#  |  size
#  |      The size, in pixels, of the arrow head.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __cached_all__overridden_defaults__ = {'fill_color': 'black', 'level':...
#  |
#  |  __cached_all__properties__ = {'fill_alpha', 'fill_color', 'js_event_ca...
#  |
#  |  __cached_all__properties_with_refs__ = {'fill_alpha', 'fill_color', 'j...
#  |
#  |  __container_props__ = set()
#  |
#  |  __dataspecs__ = {'fill_alpha': <bokeh.core.property.descriptors.DataSp...
#  |
#  |  __overridden_defaults__ = {'fill_color': 'black'}
#  |
#  |  __properties__ = {'fill_alpha', 'fill_color', 'line_alpha', 'line_cap'...
#  |
#  |  __properties_with_refs__ = {'fill_alpha', 'fill_color', 'line_alpha', ...
#  |
#  |  __view_model__ = 'VeeHead'
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from bokeh.models.annotations.Annotation:
#  |
#  |  plot
#  |      The plot to which this annotation is attached.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from bokeh.models.renderers.Renderer:
#  |
#  |  level
#  |      Specifies the level in which to paint this renderer.
#  |
#  |  visible
#  |      Is the renderer visible.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from bokeh.model.Model:
#  |
#  |  __init__(self, **kwargs)
#  |
#  |  __repr__ = __str__(self)
#  |      Return str(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  js_on_change(self, event, *callbacks)
#  |      Attach a CustomJS callback to an arbitrary BokehJS model event.
#  |
#  |      On the BokehJS side, change events for model properties have the
#  |      form ``"change:property_name"``. As a convenience, if the event name
#  |      passed to this method is also the name of a property on the model,
#  |      then it will be prefixed with ``"change:"`` automatically:
#  |
#  |      .. code:: python
#  |
#  |          # these two are equivalent
#  |          source.js_on_change('data', callback)
#  |          source.js_on_change('change:data', callback)
#  |
#  |      However, there are other kinds of events that can be useful to respond
#  |      to, in addition to property change events. For example to run a
#  |      callback whenever data is streamed to a ``ColumnDataSource``, use the
#  |      ``"stream"`` event on the source:
#  |
#  |      .. code:: python
#  |
#  |          source.js_on_change('streaming', callback)
#  |
#  |  js_on_event(self, event, *callbacks)
#  |
#  |  layout(self, side, plot)
#  |
#  |  on_change(self, attr, *callbacks)
#  |      Add a callback on this object to trigger when ``attr`` changes.
#  |
#  |      Args:
#  |          attr (str) : an attribute name on this object
#  |          callback (callable) : a callback function to register
#  |
#  |      Returns:
#  |          None
#  |
#  |  references(self)
#  |      Returns all ``Models`` that this object has references to.
#  |
#  |  select(self, selector)
#  |      Query this object and all of its references for objects that
#  |      match the given selector.
#  |
#  |      Args:
#  |          selector (JSON-like) :
#  |
#  |      Returns:
#  |          seq[Model]
#  |
#  |  select_one(self, selector)
#  |      Query this object and all of its references for objects that
#  |      match the given selector.  Raises an error if more than one object
#  |      is found.  Returns single matching object, or None if nothing is found
#  |      Args:
#  |          selector (JSON-like) :
#  |
#  |      Returns:
#  |          Model
#  |
#  |  set_select(self, selector, updates)
#  |      Update objects that match a given selector with the specified
#  |      attribute/value updates.
#  |
#  |      Args:
#  |          selector (JSON-like) :
#  |          updates (dict) :
#  |
#  |      Returns:
#  |          None
#  |
#  |  to_json(self, include_defaults)
#  |      Returns a dictionary of the attributes of this object,
#  |      containing only "JSON types" (string, number, boolean,
#  |      none, dict, list).
#  |
#  |      References to other objects are serialized as "refs" (just
#  |      the object ID and type info), so the deserializer will
#  |      need to separately have the full attributes of those
#  |      other objects.
#  |
#  |      There's no corresponding from_json() because to
#  |      deserialize an object is normally done in the context of a
#  |      Document (since the Document can resolve references).
#  |
#  |      For most purposes it's best to serialize and deserialize
#  |      entire documents.
#  |
#  |      Args:
#  |          include_defaults (bool) : whether to include attributes
#  |              that haven't been changed from the default
#  |
#  |  to_json_string(self, include_defaults)
#  |      Returns a JSON string encoding the attributes of this object.
#  |
#  |      References to other objects are serialized as references
#  |      (just the object ID and type info), so the deserializer
#  |      will need to separately have the full attributes of those
#  |      other objects.
#  |
#  |      There's no corresponding from_json_string() because to
#  |      deserialize an object is normally done in the context of a
#  |      Document (since the Document can resolve references).
#  |
#  |      For most purposes it's best to serialize and deserialize
#  |      entire documents.
#  |
#  |      Args:
#  |          include_defaults (bool) : whether to include attributes
#  |              that haven't been changed from the default
#  |
#  |  trigger(self, attr, old, new, hint=None, setter=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from bokeh.model.Model:
#  |
#  |  document
#  |      The |Document| this model is attached to (can be ``None``)
#  |
#  |  js_event_callbacks
#  |      A mapping of event names to lists of CustomJS callbacks.
#  |
#  |      Typically, rather then modifying this property directly, callbacks should be
#  |      added using the ``Model.js_on_event`` method:
#  |
#  |      .. code:: python
#  |
#  |          callback = CustomJS(code="console.log('tap event occured')")
#  |          plot.js_on_event('tap', callback)
#  |
#  |  js_property_callbacks
#  |      A mapping of attribute names to lists of CustomJS callbacks, to be set up on
#  |      BokehJS side when the document is created.
#  |
#  |      Typically, rather then modifying this property directly, callbacks should be
#  |      added using the ``Model.js_on_change`` method:
#  |
#  |      .. code:: python
#  |
#  |          callback = CustomJS(code="console.log('stuff')")
#  |          plot.x_range.js_on_change('start', callback)
#  |
#  |  name
#  |      An arbitrary, user-supplied name for this model.
#  |
#  |      This name can be useful when querying the document to retrieve specific
#  |      Bokeh models.
#  |
#  |      .. code:: python
#  |
#  |          >>> plot.circle([1,2,3], [4,5,6], name="temp")
#  |          >>> plot.select(name="temp")
#  |          [GlyphRenderer(id='399d53f5-73e9-44d9-9527-544b761c7705', ...)]
#  |
#  |      .. note::
#  |          No uniqueness guarantees or other conditions are enforced on any names
#  |          that are provided, nor is the name used directly by Bokeh for any
#  |          reason.
#  |
#  |  ref
#  |      A Bokeh protocol "reference" to this model, i.e. a dict of the
#  |      form:
#  |
#  |      .. code-block:: python
#  |
#  |          {
#  |              'type' : << view model name >>
#  |              'id'   : << unique model id >>
#  |          }
#  |
#  |      Additionally there may be a `subtype` field if this model is a subtype.
#  |
#  |  subscribed_events
#  |      List of events that are subscribed to by Python callbacks. This is
#  |      the set of events that will be communicated from BokehJS back to
#  |      Python for this model.
#  |
#  |  tags
#  |      An optional list of arbitrary, user-supplied values to attach to this
#  |      model.
#  |
#  |      This data can be useful when querying the document to retrieve specific
#  |      Bokeh models:
#  |
#  |      .. code:: python
#  |
#  |          >>> r = plot.circle([1,2,3], [4,5,6])
#  |          >>> r.tags = ["foo", 10]
#  |          >>> plot.select(tags=['foo', 10])
#  |          [GlyphRenderer(id='1de4c3df-a83d-480a-899b-fb263d3d5dd9', ...)]
#  |
#  |      Or simply a convenient way to attach any necessary metadata to a model
#  |      that can be accessed by CustomJS callbacks, etc.
#  |
#  |      .. note::
#  |          No uniqueness guarantees or other conditions are enforced on any tags
#  |          that are provided, nor are the tags used directly by Bokeh for any
#  |          reason.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from bokeh.core.has_props.HasProps:
#  |
#  |  __setattr__(self, name, value)
#  |      Intercept attribute setting on HasProps in order to special case
#  |      a few situations:
#  |
#  |      * short circuit all property machinery for ``_private`` attributes
#  |      * handle setting ``__deprecated_attributes__``
#  |      * suggest similar attribute names on attribute errors
#  |
#  |      Args:
#  |          name (str) : the name of the attribute to set on this object
#  |          value (obj) : the value to set
#  |
#  |      Returns:
#  |          None
#  |
#  |  apply_theme(self, property_values)
#  |      Apply a set of theme values which will be used rather than
#  |      defaults, but will not override application-set values.
#  |
#  |      The passed-in dictionary may be kept around as-is and shared with
#  |      other instances to save memory (so neither the caller nor the
#  |      |HasProps| instance should modify it).
#  |
#  |      Args:
#  |          property_values (dict) : theme values to use in place of defaults
#  |
#  |      Returns:
#  |          None
#  |
#  |  equals(self, other)
#  |      Structural equality of models.
#  |
#  |      Args:
#  |          other (HasProps) : the other instance to compare to
#  |
#  |      Returns:
#  |          True, if properties are structurally equal, otherwise False
#  |
#  |  pprint(self, verbose=False, max_width=79, newline='\n')
#  |      Print a "pretty" string representation of the object to stdout.
#  |
#  |      .. note::
#  |          This function only functions in the IPython shell or
#  |          Jupyter Notebooks.
#  |
#  |      Args:
#  |          Verbose (bool, optional) :
#  |              This is a conventional argument for IPython representation
#  |              printers but is unused by Bokeh. (default: False)
#  |
#  |          max_width (int, optional) :
#  |              Minimum width to start breaking lines when possible. (default: 79)
#  |
#  |          newline (str, optional) :
#  |              Character to use to separate each line (default: ``\n``)
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ValueError, if ``IPython`` cannot be imported
#  |
#  |      Examples:
#  |
#  |          .. code-block:: python
#  |
#  |              In [1]: from bokeh.models import Range1d
#  |
#  |              In [1]: r = Range1d(start=10, end=20)
#  |
#  |              In [2]: r.pprint()
#  |              bokeh.models.ranges.Range1d(
#  |                  id='1576d21a-0c74-4214-8d8f-ad415e1e4ed4',
#  |                  bounds=None,
#  |                  callback=None,
#  |                  end=20,
#  |                  js_property_callbacks={},
#  |                  max_interval=None,
#  |                  min_interval=None,
#  |                  name=None,
#  |                  start=10,
#  |                  tags=[])
#  |
#  |  pretty(self, verbose=False, max_width=79, newline='\n')
#  |      Generate a "pretty" string representation of the object.
#  |
#  |      .. note::
#  |          This function only functions in the IPython shell or
#  |          Jupyter Notebooks.
#  |
#  |      Args:
#  |          Verbose (bool, optional) :
#  |              This is a conventional argument for IPython representation
#  |              printers but is unused by Bokeh. (default: False)
#  |
#  |          max_width (int, optional) :
#  |              Minimum width to start breaking lines when possible. (default: 79)
#  |
#  |          newline (str, optional) :
#  |              Character to use to separate each line (default: ``\n``)
#  |
#  |      Returns:
#  |          str : pretty object representation
#  |
#  |      Raises:
#  |          ValueError, if ``IPython`` cannot be imported
#  |
#  |  properties_with_values(self, include_defaults=True)
#  |      Collect a dict mapping property names to their values.
#  |
#  |      This method *always* traverses the class hierarchy and includes
#  |      properties defined on any parent classes.
#  |
#  |      Non-serializable properties are skipped and property values are in
#  |      "serialized" format which may be slightly different from the values
#  |      you would normally read from the properties; the intent of this method
#  |      is to return the information needed to losslessly reconstitute the
#  |      object instance.
#  |
#  |      Args:
#  |          include_defaults (bool, optional) :
#  |              Whether to include properties that haven't been explicitly set
#  |              since the object was created. (default: True)
#  |
#  |      Returns:
#  |         dict : mapping from property names to their values
#  |
#  |  query_properties_with_values(self, query, include_defaults=True)
#  |      Query the properties values of |HasProps| instances with a
#  |      predicate.
#  |
#  |      Args:
#  |          query (callable) :
#  |              A callable that accepts property descriptors and returns True
#  |              or False
#  |
#  |          include_defaults (bool, optional) :
#  |              Whether to include properties that have not been explicitly
#  |              set by a user (default: True)
#  |
#  |      Returns:
#  |          dict : mapping of property names and values for matching properties
#  |
#  |  set_from_json(self, name, json, models=None, setter=None)
#  |      Set a property value on this object from JSON.
#  |
#  |      Args:
#  |          name: (str) : name of the attribute to set
#  |
#  |          json: (JSON-value) : value to set to the attribute to
#  |
#  |          models (dict or None, optional) :
#  |              Mapping of model ids to models (default: None)
#  |
#  |              This is needed in cases where the attributes to update also
#  |              have values that have references.
#  |
#  |          setter(ClientSession or ServerSession or None, optional) :
#  |              This is used to prevent "boomerang" updates to Bokeh apps.
#  |
#  |              In the context of a Bokeh server application, incoming updates
#  |              to properties will be annotated with the session that is
#  |              doing the updating. This value is propagated through any
#  |              subsequent change notifications that the update triggers.
#  |              The session can compare the event setter to itself, and
#  |              suppress any updates that originate from itself.
#  |
#  |      Returns:
#  |          None
#  |
#  |  themed_values(self)
#  |      Get any theme-provided overrides.
#  |
#  |      Results are returned as a dict from property name to value, or
#  |      ``None`` if no theme overrides any values for this instance.
#  |
#  |      Returns:
#  |          dict or None
#  |
#  |  unapply_theme(self)
#  |      Remove any themed values and restore defaults.
#  |
#  |      Returns:
#  |          None
#  |
#  |  update(self, **kwargs)
#  |      Updates the object's properties from the given keyword arguments.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Examples:
#  |
#  |          The following are equivalent:
#  |
#  |          .. code-block:: python
#  |
#  |              from bokeh.models import Range1d
#  |
#  |              r = Range1d
#  |
#  |              # set properties individually:
#  |              r.start = 10
#  |              r.end = 20
#  |
#  |              # update properties together:
#  |              r.update(start=10, end=20)
#  |
#  |  update_from_json(self, json_attributes, models=None, setter=None)
#  |      Updates the object's properties from a JSON attributes dictionary.
#  |
#  |      Args:
#  |          json_attributes: (JSON-dict) : attributes and values to update
#  |
#  |          models (dict or None, optional) :
#  |              Mapping of model ids to models (default: None)
#  |
#  |              This is needed in cases where the attributes to update also
#  |              have values that have references.
#  |
#  |          setter(ClientSession or ServerSession or None, optional) :
#  |              This is used to prevent "boomerang" updates to Bokeh apps.
#  |
#  |              In the context of a Bokeh server application, incoming updates
#  |              to properties will be annotated with the session that is
#  |              doing the updating. This value is propagated through any
#  |              subsequent change notifications that the update triggers.
#  |              The session can compare the event setter to itself, and
#  |              suppress any updates that originate from itself.
#  |
#  |      Returns:
#  |          None
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from bokeh.core.has_props.HasProps:
#  |
#  |  dataspecs() from bokeh.model.MetaModel
#  |      Collect the names of all ``DataSpec`` properties on this class.
#  |
#  |      This method *always* traverses the class hierarchy and includes
#  |      properties defined on any parent classes.
#  |
#  |      Returns:
#  |          set[str] : names of DataSpec properties
#  |
#  |  dataspecs_with_props() from bokeh.model.MetaModel
#  |      Collect a dict mapping the names of all ``DataSpec`` properties
#  |      on this class to the associated properties.
#  |
#  |      This method *always* traverses the class hierarchy and includes
#  |      properties defined on any parent classes.
#  |
#  |      Returns:
#  |          dict[str, DataSpec] : mapping of names and ``DataSpec`` properties
#  |
#  |  lookup(name) from bokeh.model.MetaModel
#  |      Find the ``PropertyDescriptor`` for a Bokeh property on a class,
#  |      given the property name.
#  |
#  |      Args:
#  |          name (str) : name of the property to search for
#  |
#  |      Returns:
#  |          PropertyDescriptor : descriptor for property named ``name``
#  |
#  |  properties(with_bases=True) from bokeh.model.MetaModel
#  |      Collect the names of properties on this class.
#  |
#  |      This method *optionally* traverses the class hierarchy and includes
#  |      properties defined on any parent classes.
#  |
#  |      Args:
#  |          with_bases (bool, optional) :
#  |              Whether to include properties defined on parent classes in
#  |              the results. (default: True)
#  |
#  |      Returns:
#  |         set[str] : property names
#  |
#  |  properties_containers() from bokeh.model.MetaModel
#  |      Collect the names of all container properties on this class.
#  |
#  |      This method *always* traverses the class hierarchy and includes
#  |      properties defined on any parent classes.
#  |
#  |      Returns:
#  |          set[str] : names of container properties
#  |
#  |  properties_with_refs() from bokeh.model.MetaModel
#  |      Collect the names of all properties on this class that also have
#  |      references.
#  |
#  |      This method *always* traverses the class hierarchy and includes
#  |      properties defined on any parent classes.
#  |
#  |      Returns:
#  |          set[str] : names of properties that have references
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from bokeh.core.has_props.HasProps:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from bokeh.util.callback_manager.PropertyCallbackManager:
#  |
#  |  remove_on_change(self, attr, *callbacks)
#  |      Remove a callback from this object
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from bokeh.util.callback_manager.EventCallbackManager:
#  |
#  |  on_event(self, event, *callbacks)

# %%
# EXERCISE: experiment with arrows and arrow heads

# %% [markdown]
# ## Legends

# %%
import numpy as np

x = np.linspace(0, 4*np.pi, 100)
y = np.sin(x)

p = figure(height=400)

p.circle(x, y, legend="sin(x)")
p.line(x, 2*y, legend="2*sin(x)", line_dash=[4, 4], line_color="orange", line_width=2)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6052c12-e934-4ddc-8ef4-66674309a846"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e6052c12-e934-4ddc-8ef4-66674309a846");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6052c12-e934-4ddc-8ef4-66674309a846");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6052c12-e934-4ddc-8ef4-66674309a846' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cda0bb9d-8a50-40a7-b101-c28cd3cc5c5e":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"491bb84d-9f36-4a6e-8c80-833c07d61399","type":"PanTool"},{"id":"11ced70e-2eb1-435e-b63d-56986d56582b","type":"WheelZoomTool"},{"id":"c85d4e85-e908-478a-879d-6230770d506d","type":"BoxZoomTool"},{"id":"a1d3c657-934a-41cb-980c-6537fe47b6a8","type":"SaveTool"},{"id":"dec33b4d-2808-46fd-937a-0050e417933f","type":"ResetTool"},{"id":"1f33c175-021a-4cf0-a224-7a690af1a758","type":"HelpTool"}]},"id":"d6507e69-ff0f-4bd0-a345-618572a0fcc8","type":"Toolbar"},{"attributes":{"data_source":{"id":"9a9afa57-2174-4f44-8c5a-61894f5818e3","type":"ColumnDataSource"},"glyph":{"id":"a2c2a043-77db-40f5-96dc-1ac93b523566","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"118ec1e4-7ecf-46f7-a500-3bbeb36b77ac","type":"Circle"},"selection_glyph":null},"id":"550769ff-0738-4155-bca8-8c243a927654","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"fac995ef-668f-4b53-94b5-258473d65978","type":"BasicTickFormatter"},"plot":{"id":"3ff78c0c-e45d-49be-9347-8c6583c14b7e","subtype":"Figure","type":"Plot"},"ticker":{"id":"a08e3f83-60ae-4f3e-be0d-a18dfba225b3","type":"BasicTicker"}},"id":"1613bdbc-9c60-4f54-84ed-423457a8d553","type":"LinearAxis"},{"attributes":{"formatter":{"id":"05107178-1a5b-4efd-96ae-0bcc99303213","type":"BasicTickFormatter"},"plot":{"id":"3ff78c0c-e45d-49be-9347-8c6583c14b7e","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec3c6ab9-5216-4c1e-8ced-ebd9f17fdbc6","type":"BasicTicker"}},"id":"47b52dea-7256-4e0c-aa4c-296088f17bf6","type":"LinearAxis"},{"attributes":{"below":[{"id":"47b52dea-7256-4e0c-aa4c-296088f17bf6","type":"LinearAxis"}],"left":[{"id":"1613bdbc-9c60-4f54-84ed-423457a8d553","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"47b52dea-7256-4e0c-aa4c-296088f17bf6","type":"LinearAxis"},{"id":"a0cf682b-9d71-48fc-8a13-dea7a510fd27","type":"Grid"},{"id":"1613bdbc-9c60-4f54-84ed-423457a8d553","type":"LinearAxis"},{"id":"e55140b6-14e4-4d1c-bdb7-fa067e0b594c","type":"Grid"},{"id":"7cec59c9-b913-4e6d-86ae-9e7e3e441e64","type":"BoxAnnotation"},{"id":"8d92a5f8-47ab-4248-aa54-d6e11d485936","type":"Legend"},{"id":"550769ff-0738-4155-bca8-8c243a927654","type":"GlyphRenderer"},{"id":"0db7ff40-cc82-4385-8ad1-91500787267f","type":"GlyphRenderer"}],"title":{"id":"75944c87-0386-475c-8984-e84e35eb34ae","type":"Title"},"tool_events":{"id":"d00f6c58-ffb8-4618-a010-7db381c8e10d","type":"ToolEvents"},"toolbar":{"id":"d6507e69-ff0f-4bd0-a345-618572a0fcc8","type":"Toolbar"},"x_range":{"id":"4dddf103-2cee-4db7-8372-99d20e024f98","type":"DataRange1d"},"x_scale":{"id":"c318a64d-4451-4d35-a52c-2d221a908964","type":"LinearScale"},"y_range":{"id":"97da418a-438a-42ed-9ff9-56ea518909fc","type":"DataRange1d"},"y_scale":{"id":"b6223b32-6512-4e28-b938-d2ba2555ad10","type":"LinearScale"}},"id":"3ff78c0c-e45d-49be-9347-8c6583c14b7e","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"sin(x)"},"renderers":[{"id":"550769ff-0738-4155-bca8-8c243a927654","type":"GlyphRenderer"}]},"id":"1c89e30a-2b6c-4bb9-946b-471fd9c392c4","type":"LegendItem"},{"attributes":{"callback":null},"id":"97da418a-438a-42ed-9ff9-56ea518909fc","type":"DataRange1d"},{"attributes":{"plot":{"id":"3ff78c0c-e45d-49be-9347-8c6583c14b7e","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec3c6ab9-5216-4c1e-8ced-ebd9f17fdbc6","type":"BasicTicker"}},"id":"a0cf682b-9d71-48fc-8a13-dea7a510fd27","type":"Grid"},{"attributes":{"plot":{"id":"3ff78c0c-e45d-49be-9347-8c6583c14b7e","subtype":"Figure","type":"Plot"}},"id":"dec33b4d-2808-46fd-937a-0050e417933f","type":"ResetTool"},{"attributes":{"data_source":{"id":"74ffdb0a-4b77-4680-8b80-55b6a7abb82b","type":"ColumnDataSource"},"glyph":{"id":"a5e3f866-8f65-436d-aa56-2893f1e20efa","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6cda8eac-2df4-4514-ba31-48221462d806","type ...

# %% [markdown]
# ### Compound legends
#
# Sometimes, two (or more) different glyphs are used with a single data source.  In this case, you can make compound legends by specifying the same legend argument to multiple glyph methods when creating a plot, as in:
#
# ```python
# p.circle(x, y, legend="sin(x)")
# p.line(x, y, legend="sin(x)", line_dash=[4, 4], line_color="orange", line_width=2)
# ```

# %%
# EXERCISE:  
# (1) Try making a compound legend 
# (2) Try moving the legend using p.legend.location.  Possible values are listed in bokeh.core.enum
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c4457742-01c5-4b93-9c2b-d70e6242094c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c4457742-01c5-4b93-9c2b-d70e6242094c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c4457742-01c5-4b93-9c2b-d70e6242094c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c4457742-01c5-4b93-9c2b-d70e6242094c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3b229706-2958-42ba-af68-15f675a3de10":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[4,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d0eb39d-ce07-4ee5-a89a-f6862b8d0aa2","type":"Line"},{"attributes":{"callback":null},"id":"f8c4f34a-b40a-45ef-9bd1-3b0943010c7f","type":"DataRange1d"},{"attributes":{"plot":{"id":"9a240469-c8d3-4e88-b0f3-1ed872bdef27","subtype":"Figure","type":"Plot"}},"id":"a5e4885c-6f5a-417b-8d56-f1f1a8ea3f99","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"56c5a92c-0d62-42c9-9ff4-01522d108882","type":"ColumnDataSource"},{"attributes":{},"id":"46b63a79-a741-4753-a881-c65d1dfa50d5","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"sin(x)"},"renderers":[{"id":"ce77c19d-7772-4f9e-9cbb-f74fc4d106b2","type":"GlyphRenderer"},{"id":"60f97df9-adaf-4a86-b6ea-5a07d1b6ab8f","type":"GlyphRenderer"}]},"id":"929fb925-bb6f-49d8-bb6d-6052b930aa35","type":"LegendItem"},{"attributes":{"overlay":{"id":"e8773397-b118-4772-bcbe-8b3575ed3777","type":"BoxAnnotation"},"plot":{"id":"9a240469-c8d3-4e88-b0f3-1ed872bdef27","subtype":"Figure","type":"Plot"}},"id":"72d2ce54-155d-46e1-9b30-73f26e857f84","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"00863be8-e704-4911-8fef-dcd7d925bc15","type":"Circle"},{"attributes":{"items":[{"id":"929fb925-bb6f-49d8-bb6d-6052b930aa35","type":"LegendItem"}],"location":"bottom_left","plot":{"id":"9a240469-c8d3-4e88-b0f3-1ed872bdef27","subtype":"Figure","type":"Plot"}},"id":"36970cd0-75b0-4f54-89ac-a3e6b0042fae","type":"Legend"},{"attributes":{"plot":{"id":"9a240469-c8d3-4e88-b0f3-1ed872bdef27","subtype":"Figure","type":"Plot"}},"id":"c4f4a9b6-e0a2-429b-8d41-6b14ee9932bb","type":"HelpTool"},{"attributes":{"line_color":{"value":"orange"},"line_dash":[4,4],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"96155c60-2a24-4156-8528-09970f5546fc","type":"Line"},{"attributes":{},"id":"06bed39d-cfde-4414-b8fa-cc687a5a2c12","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"015810f5-8080-4efe-84ca-396919c6c98d","type":"PanTool"},{"id":"a5e4885c-6f5a-417b-8d56-f1f1a8ea3f99","type":"WheelZoomTool"},{"id":"72d2ce54-155d-46e1-9b30-73f26e857f84","type":"BoxZoomTool"},{"id":"c22af915-f65d-4714-ac1a-414e1e0c57ba","type":"SaveTool"},{"id":"1fb76dd2-7cec-420d-b62e-b3213481624a","type":"ResetTool"},{"id":"c4f4a9b6-e0a2-429b-8d41-6b14ee9932bb","type":"HelpTool"}]},"id":"5d1f64be-908b-4bcc-b083-a52a0b5a61ab","type":"Toolbar"},{"attributes":{},"id":"a9db7e9c-b0c6-4fe3-8f59-3c8d1fd31e75","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"9a240469-c8d3-4e88-b0f3-1ed872bdef27","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9db7e9c-b0c6-4fe3-8f59-3c8d1fd31e75","type":"BasicTicker"}},"id":"d5cf4083-2035-4f60-a998-4ea5bd2986f0","type":"Grid"},{"attributes":{"data_source":{"id":"56c5a92c-0d62-42c9-9ff4-01522d108882","type":"ColumnDataSource"},"glyph":{"id":"96155c60-2a24-4156-8528-09970f5546fc","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0d0eb39d-ce07-4ee5-a89a-f6862b8d0aa2","type":"Line"},"selection_glyph":null},"id":"60f97df9-adaf-4a86-b6ea-5a07d1b6ab8f","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e8773397-b118-4772-bcbe-8b3575ed3777","type":"BoxAnnotation"},{"attributes":{"data_so ...

# %% [markdown]
# ## Color bars

# %%
from bokeh.sampledata.autompg import autompg
from bokeh.models import LinearColorMapper, ColorBar
from bokeh.palettes import Viridis256
source = ColumnDataSource(autompg)
color_mapper = LinearColorMapper(palette=Viridis256, low=autompg.weight.min(), high=autompg.weight.max())

p = figure(x_axis_label='Year', y_axis_label='MPG', tools='', toolbar_location='above')
p.circle(x='yr', y='mpg', color={'field': 'weight', 'transform': color_mapper}, size=20, alpha=0.6, source=source)
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=12, location=(0,0), title='Weight')
p.add_layout(color_bar, 'right')

show(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-c80adfbf212f> in <module>()
# ----> 1 from bokeh.sampledata.autompg import autompg
#       2 from bokeh.models import LinearColorMapper, ColorBar
#       3 from bokeh.palettes import Viridis256
#       4 source = ColumnDataSource(autompg)
#       5 color_mapper = LinearColorMapper(palette=Viridis256, low=autompg.weight.min(), high=autompg.weight.max())
#
# C:\Users\ZekeLabs\Anaconda3\lib\site-packages\bokeh\sampledata\autompg.py in <module>()
#       6 from bokeh.util.dependencies import import_required
#       7 pd = import_required('pandas',
# ----> 8               'autompg sample data requires Pandas (http://pandas.pydata.org) to be installed')
#       9
#      10 from os.path import dirname, join
#
# C:\Users\ZekeLabs\Anaconda3\lib\site-packages\bokeh\util\dependencies.py in import_required(mod_name, error_msg)
#      48     '''
#      49     try:
# ---> 50         return import_module(mod_name)
#      51     except ImportError:
#      52         raise RuntimeError(error_msg)
#
# C:\Users\ZekeLabs\Anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# C:\Users\ZekeLabs\Anaconda3\lib\site-packages\pandas\__init__.py in <module>()
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat.numpy import *
#      23
#      24 try:
#
# C:\Users\ZekeLabs\Anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py in <module>()
#       8
#       9 # numpy versioning
# ---> 10 _np_version = np.version.short_version
#      11 _nlv = LooseVersion(_np_version)
#      12 _np_version_under1p8 = _nlv < '1.8'
#
# AttributeError: module 'numpy' has no attribute 'version'

# %%
import numpy.__version__
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-d202e1d27e65> in <module>()
# ----> 1 import numpy.__version__
#
# ImportError: No module named 'numpy.__version__'

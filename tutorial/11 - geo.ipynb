# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>11. Geographic Data</h2></div>

# %% [markdown]
# It is often useful to be able to relate datasets with their real-world context.  You can plot geographic data just like any other type of data, as in the [Texas Unemployment example](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/gallery/texas.ipynb), but Bokeh also Bokeh provides several specialized mechanisms for plotting data in geographic coordinates:
#
# * [TileSource](http://bokeh.pydata.org/en/latest/docs/reference/models/tiles.html), especially WMTSTileSource: allows data to be overlaid on data from any map tile server, including [Google Maps](http://maps.google.com), [Stamen](http://maps.stamen.com), [MapQuest](https://www.mapquest.com/), [OpenStreetMap](https://www.openstreetmap.org), [ESRI](http://www.esri.com), and custom servers.
# * [GeoJSONDataSource](http://bokeh.pydata.org/en/0.11.1/docs/user_guide/geo.html#geojson-datasource): Allows reading data in [GeoJSON](http://geojson.org/) format and using it just like any other ColumnDataSource.
# * GMapPlot: older, more limited interface just to Google Maps (GMapPlot); obsoleted by TileSource.
#
# Here we will briefly demonstrate how to use a WTMS tile source along with your data.

# %% [markdown]
# # WMTS Tile Source
#
# WTMS is the most common web standard for tiled map data, i.e. maps supplied as standard-sized image patches from which the overall map can be constructed at a given zoom level.  WTMS uses Web Mercator format, measuring distances from Greenwich, England as meters north and meters west, which is easy to compute but does distort the global shape.
#
# First let's create an empty Bokeh plot covering the USA, with bounds specified in meters:

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="66191036-5b41-485d-a121-4679d9a74d6c">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure
from bokeh.tile_providers import WMTSTileSource

USA = x_range,y_range = ((-13884029,-7453304), (2698291,6455972))

fig = figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
fig.axis.visible = False

# %% [markdown]
# A few WTMS tile sources are already defined in `bokeh.tile_providers`, but here we'll show how to specify the interface using a format string showing Bokeh how to request a tile with the required zoom, x, and y values from a given tile provider:

# %%
url = 'http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png'
attribution = "Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL"

fig.add_tile(WMTSTileSource(url=url, attribution=attribution))
# Out:
# TileRenderer(id='277791f0-9a18-42f7-b5a8-bf0630ec1f88', ...)

# %% [markdown]
# If you show the figure, you can then use the wheel zoom and pan tools to navigate over any zoom level, and Bokeh will request the appropriate tiles from the server and insert them at the correct locations in the plot:

# %%
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="59deac4a-3a9f-4aeb-89b8-48cf2df15782"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("59deac4a-3a9f-4aeb-89b8-48cf2df15782");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("59deac4a-3a9f-4aeb-89b8-48cf2df15782");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '59deac4a-3a9f-4aeb-89b8-48cf2df15782' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d339d2da-5b75-4f42-bbab-b3ef802eaf20":{"roots":{"references":[{"attributes":{"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"}},"id":"7cbd3ee7-4aa0-4ad4-a4e1-f2374d30aa80","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"}},"id":"dd86af9e-b02d-4c36-b774-ee1aa49a01e4","type":"PanTool"},{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"98dbd577-2898-4cff-a78f-4dc4e4036c52","type":"Range1d"},{"attributes":{"below":[{"id":"85e7f7d4-0389-485b-9386-77bb118b4c0d","type":"LinearAxis"}],"left":[{"id":"e235315d-8c43-45fc-b392-fb64eda4609d","type":"LinearAxis"}],"renderers":[{"id":"85e7f7d4-0389-485b-9386-77bb118b4c0d","type":"LinearAxis"},{"id":"f064169b-bd3f-4fd9-ae0e-0ab229504445","type":"Grid"},{"id":"e235315d-8c43-45fc-b392-fb64eda4609d","type":"LinearAxis"},{"id":"c7e0e462-3eb1-4d32-bde4-180e8692d4f7","type":"Grid"},{"id":"277791f0-9a18-42f7-b5a8-bf0630ec1f88","type":"TileRenderer"}],"title":{"id":"b04ea0b7-4753-438e-8ab3-053b34c82146","type":"Title"},"tool_events":{"id":"8966890b-6260-4313-99cc-f228dc365bf9","type":"ToolEvents"},"toolbar":{"id":"385413f8-1b56-46e5-92fc-b48db744cbc0","type":"Toolbar"},"x_range":{"id":"98dbd577-2898-4cff-a78f-4dc4e4036c52","type":"Range1d"},"x_scale":{"id":"4d1fdf5d-f49d-420c-824f-d4133798f37b","type":"LinearScale"},"y_range":{"id":"e4eb65b3-7034-4cc7-8ab8-5933437fe383","type":"Range1d"},"y_scale":{"id":"71fde1b3-42e7-4b67-9f38-f94442648469","type":"LinearScale"}},"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c3131e31-0a81-4b9f-b0c9-2848b0b285b4","type":"BasicTicker"},{"attributes":{},"id":"419c29f4-9f06-4620-a799-2da085d17bc6","type":"BasicTickFormatter"},{"attributes":{},"id":"8966890b-6260-4313-99cc-f228dc365bf9","type":"ToolEvents"},{"attributes":{},"id":"13ad21c6-f221-46ab-8e56-9454ca64210d","type":"BasicTickFormatter"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"0060dd6c-a1b9-456e-9952-94dddff84929","type":"WMTSTileSource"},{"attributes":{},"id":"4d1fdf5d-f49d-420c-824f-d4133798f37b","type":"LinearScale"},{"attributes":{"formatter":{"id":"13ad21c6-f221-46ab-8e56-9454ca64210d","type":"BasicTickFormatter"},"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"},"ticker":{"id":"3243a82b-d305-4f05-ae8e-1a33d9e80fbf","type":"BasicTicker"},"visible":false},"id":"85e7f7d4-0389-485b-9386-77bb118b4c0d","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"b04ea0b7-4753-438e-8ab3-053b34c82146","type":"Title"},{"attributes":{},"id":"3243a82b-d305-4f05-ae8e-1a33d9e80fbf","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dd86af9e-b02d-4c36-b774-ee1aa49a01e4","type":"PanTool"},{"id":"7cbd3ee7-4aa0-4ad4-a4e1-f2374d30aa80","type":"WheelZoomTool"}]},"id":"385413f8-1b56-46e5-92fc-b48db744cbc0","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3131e31-0a81-4b9f-b0c9-2848b0b285b4","type":"BasicTicker"}},"id":"c7e0e462-3eb1-4d32-bde4-180e8692d4f7","type":"Grid"},{"attributes":{},"id":"71fde1b3-42e7-4b67-9f38-f94442648469","type":"LinearScale"},{"attributes":{"callback":null,"end":6455972,"start":2698291},"id":"e4eb65b3-7034-4cc7-8ab8-5933437fe383","type":"Range1d"},{"attributes":{"formatter":{"id":"419c29f4-9f06-4620-a799-2da085d17bc6","type":"BasicTickFormatter"},"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3131e31-0a81-4b9f-b0c9-2848b0b285b4","type":"BasicTicker"},"visible":false},"id":"e235315d-8c43-45fc-b392-fb64eda4609d","type":"LinearAxis"},{"attributes":{"plot":{"id":"091b811c-e595-41 ...
#             var render_items = [{"docid":"d339d2da-5b75-4f42-

# %% [markdown]
# That's all it takes to put map data into your plot!  Of course, you'll usually want to show other data as well, or you could just use the tile server's own web address. You can now add anything you would normally use in a Bokeh plot, as long as you can obtain coordinates for it in Web Mercator format.  For example:

# %%
import pandas as pd
import numpy as np

def wgs84_to_web_mercator(df, lon="lon", lat="lat"):
    """Converts decimal longitude/latitude to Web Mercator format"""
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

df = pd.DataFrame(dict(name=["Austin","NYC"],lon=[-97.7431,-74.0059],lat=[30.2672,40.7128]))
wgs84_to_web_mercator(df)
# Out:
#        lat      lon    name             x             y
# 0  30.2672 -97.7431  Austin -1.088071e+07  3.537942e+06
# 1  40.7128 -74.0059     NYC -8.238299e+06  4.970072e+06

# %%
fig.circle(x=df['x'], y=df['y'],fill_color='blue', size=10)
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="630839b8-482a-4e3b-8696-da69160d8309"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("630839b8-482a-4e3b-8696-da69160d8309");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("630839b8-482a-4e3b-8696-da69160d8309");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '630839b8-482a-4e3b-8696-da69160d8309' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7270af40-5c46-4386-8dee-ee5d58e191b5":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"79805345-fd08-4bdc-bac1-255c605514e3","type":"Circle"},{"attributes":{"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"}},"id":"dd86af9e-b02d-4c36-b774-ee1aa49a01e4","type":"PanTool"},{"attributes":{},"id":"419c29f4-9f06-4620-a799-2da085d17bc6","type":"BasicTickFormatter"},{"attributes":{},"id":"13ad21c6-f221-46ab-8e56-9454ca64210d","type":"BasicTickFormatter"},{"attributes":{},"id":"4d1fdf5d-f49d-420c-824f-d4133798f37b","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"},"ticker":{"id":"c3131e31-0a81-4b9f-b0c9-2848b0b285b4","type":"BasicTicker"}},"id":"c7e0e462-3eb1-4d32-bde4-180e8692d4f7","type":"Grid"},{"attributes":{"data_source":{"id":"0babc183-6d12-46e6-8bb2-1ddadd7f5e48","type":"ColumnDataSource"},"glyph":{"id":"5ac7b9a3-087a-4595-bf74-c0722459ec35","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"79805345-fd08-4bdc-bac1-255c605514e3","type":"Circle"},"selection_glyph":null},"id":"12d98cf0-d74d-43c9-893e-2994ae87bcfd","type":"GlyphRenderer"},{"attributes":{},"id":"71fde1b3-42e7-4b67-9f38-f94442648469","type":"LinearScale"},{"attributes":{},"id":"c3131e31-0a81-4b9f-b0c9-2848b0b285b4","type":"BasicTicker"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"0060dd6c-a1b9-456e-9952-94dddff84929","type":"WMTSTileSource"},{"attributes":{"tile_source":{"id":"0060dd6c-a1b9-456e-9952-94dddff84929","type":"WMTSTileSource"}},"id":"277791f0-9a18-42f7-b5a8-bf0630ec1f88","type":"TileRenderer"},{"attributes":{"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"}},"id":"7cbd3ee7-4aa0-4ad4-a4e1-f2374d30aa80","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"85e7f7d4-0389-485b-9386-77bb118b4c0d","type":"LinearAxis"}],"left":[{"id":"e235315d-8c43-45fc-b392-fb64eda4609d","type":"LinearAxis"}],"renderers":[{"id":"85e7f7d4-0389-485b-9386-77bb118b4c0d","type":"LinearAxis"},{"id":"f064169b-bd3f-4fd9-ae0e-0ab229504445","type":"Grid"},{"id":"e235315d-8c43-45fc-b392-fb64eda4609d","type":"LinearAxis"},{"id":"c7e0e462-3eb1-4d32-bde4-180e8692d4f7","type":"Grid"},{"id":"277791f0-9a18-42f7-b5a8-bf0630ec1f88","type":"TileRenderer"},{"id":"12d98cf0-d74d-43c9-893e-2994ae87bcfd","type":"GlyphRenderer"}],"title":{"id":"b04ea0b7-4753-438e-8ab3-053b34c82146","type":"Title"},"tool_events":{"id":"8966890b-6260-4313-99cc-f228dc365bf9","type":"ToolEvents"},"toolbar":{"id":"385413f8-1b56-46e5-92fc-b48db744cbc0","type":"Toolbar"},"x_range":{"id":"98dbd577-2898-4cff-a78f-4dc4e4036c52","type":"Range1d"},"x_scale":{"id":"4d1fdf5d-f49d-420c-824f-d4133798f37b","type":"LinearScale"},"y_range":{"id":"e4eb65b3-7034-4cc7-8ab8-5933437fe383","type":"Range1d"},"y_scale":{"id":"71fde1b3-42e7-4b67-9f38-f94442648469","type":"LinearScale"}},"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"98dbd577-2898-4cff-a78f-4dc4e4036c52","type":"Range1d"},{"attributes":{},"id":"8966890b-6260-4313-99cc-f228dc365bf9","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"TJjbA9nAZMGf/KLGNm1fwQ==","dtype":"float64","shape":[2]},"y":{"__ndarray__":"bqXdLQv+SkFnqxDllfVSQQ==","dtype":"float64","shape":[2]}}},"id":"0babc183-6d12-46e6-8bb2-1ddadd7f5e48","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"419c29f4-9f06-4620-a799-2da085d17bc6","type":"BasicTickFormatter"},"plot":{"id":"091b811c-e595-4187-b1f4-7f70c5865c78","subtype":"Fig ...

# %%
### EXERCISE: find some data in lat, lon (e.g. at http://data.gov), 
### import it into a dataframe or data source, and add it on the map above.

# %%
from bokeh.io import output_file, show
from bokeh.plotting import figure
from bokeh.tile_providers import STAMEN_TONER

bound = 20000000 # meters
fig = figure(tools='pan, wheel_zoom', x_range=(-bound, bound), y_range=(-bound, bound))
fig.axis.visible = False
fig.add_tile(STAMEN_TONER)
output_file("stamen_toner_plot.html")

def wgs84_to_web_mercator(df, lon="lon", lat="lat"):
    """Converts decimal longitude/latitude to Web Mercator format"""
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

df = pd.DataFrame(dict(name=["Bangalore","Austin"],lon=[77.59, -97.7431],lat=[12.97, 30.2672]))
wgs84_to_web_mercator(df)
fig.circle(x=df['x'], y=df['y'],fill_color='blue', size=10)

lat = np.linspace (df.iloc[0]['lat'], df.iloc[1]['lat'],1000)
lon = np.linspace (df.iloc[0]['lon'], df.iloc[1]['lon'],1000)

fdf = pd.DataFrame({'lat':lat, 'lon':lon})

wgs84_to_web_mercator(fdf)



fig.line(fdf['x'],fdf['y'], line_width=2)
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b27b7b61-f026-4838-ae9b-76e47aa67b9a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b27b7b61-f026-4838-ae9b-76e47aa67b9a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b27b7b61-f026-4838-ae9b-76e47aa67b9a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b27b7b61-f026-4838-ae9b-76e47aa67b9a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d6ffbb34-0df8-457a-b955-c6832cec2c82":{"roots":{"references":[{"attributes":{},"id":"9b0d5e93-8199-414c-9016-595a84a35936","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"4369d984-75dd-4e6a-9a10-20387183d625","type":"Circle"},{"attributes":{},"id":"9cfc7407-2cf8-4b65-af81-560eb4abab15","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"6e8992c1-bddf-4d72-9517-9b3f96107c22","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"6e8992c1-bddf-4d72-9517-9b3f96107c22","type":"ColumnDataSource"},"glyph":{"id":"307e2bba-31c0-40f8-a9a7-ec460707c1ed","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dd7e2095-410e-4fb4-94e5-789b5c6dda20","type":"Line"},"selection_glyph":null},"id":"39b7bc90-d571-48e2-a452-d3470c589b54","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"4c245bec-b441-4b84-a4e5-f292f257d408","subtype":"Figure","type":"Plot"}},"id":"b07318a1-50ab-4843-9959-7abdc7def401","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"4c245bec-b441-4b84-a4e5-f292f257d408","subtype":"Figure","type":"Plot"}},"id":"10af8651-2432-4cd6-bd41-30260fc75b58","type":"PanTool"},{"attributes":{"callback":null,"end":20000000,"start":-20000000},"id":"2e715ae8-2184-4d0d-a9a6-84bfa10e8bd5","type":"Range1d"},{"attributes":{"tile_source":{"id":"3b54b83d-8a2d-4307-8841-788d6a3fe7fb","type":"WMTSTileSource"}},"id":"874057fb-5315-41f2-9903-caabbe7f388e","type":"TileRenderer"},{"attributes":{"data_source":{"id":"3dfb6dd5-6c1b-4434-aa03-1dbb9f44d8d5","type":"ColumnDataSource"},"glyph":{"id":"4369d984-75dd-4e6a-9a10-20387183d625","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"02f835a9-b7aa-486a-9854-2f38b350d410","type":"Circle"},"selection_glyph":null},"id":"705fd765-cfd9-4c79-a1d4-1e4a96895647","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"f3821949-e1df-45a8-9ab4-e8c9941639b9","type":"Title"},{"attributes":{},"id":"6ae0f451-9620-4ab6-835a-ff39e135ac74","type":"LinearScale"},{"attributes":{"formatter":{"id":"9b0d5e93-8199-414c-9016-595a84a35936","type":"BasicTickFormatter"},"plot":{"id":"4c245bec-b441-4b84-a4e5-f292f257d408","subtype":"Figure","type":"Plot"},"ticker":{"id":"9cfc7407-2cf8-4b65-af81-560eb4abab15","type":"BasicTicker"},"visible":false},"id":"ecfb44db-c499-4719-ac07-335e93fdbd21","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd7e2095-410e-4fb4-94e5-789b5c6dda20","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"307e2bba-31c0-40f8-a9a7-ec460707c1ed","type":"Line"},{"attributes":{},"id":"53b7dcd4-75dd-4c20-ad83-75029b9a17ad","type":"LinearScale"},{"attributes":{},"id":"c4546dbb-9a8e-4a29-a039-964d29268e49","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"02f835a9-b7aa-486a-9854-2f38b350d410","type":"Circle"},{"attributes":{"formatter":{"id":"f689a80f-943b-49a0-9dcb-542d11cdb050","type":"BasicTickFormatter"},"plot":{"id":"4c245bec-b441-4b84-a4e5-f292f257d408","subtype":"Figure","type":"Plot"},"ticker":{"id":"c4546dbb-9a8e-4a29-a039-964d29268e49","type":"BasicTicker"},"visible":false},"id":"fbe55906-fb5c-410b-ba11-5e0401ee3a09","type":"LinearAxis"},{"attributes":{},"id":"724ff996-dec8-494d-9fe2-e948963499df","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"4c245bec-b441-4b84-a4e5-f292f257d408","subtype":"Figure","type":"Plot"},"ticke ...

# %%
fdf
# Out:
#            lat        lon
# 0    12.970000  77.590000
# 1    12.987315  77.414491
# 2    13.004629  77.238983
# 3    13.021944  77.063474
# 4    13.039258  76.887966
# 5    13.056573  76.712457
# 6    13.073887  76.536948
# 7    13.091202  76.361440
# 8    13.108516  76.185931
# 9    13.125831  76.010423
# 10   13.143145  75.834914
# 11   13.160460  75.659405
# 12   13.177774  75.483897
# 13   13.195089  75.308388
# 14   13.212403  75.132879
# 15   13.229718  74.957371
# 16   13.247032  74.781862
# 17   13.264347  74.606354
# 18   13.281661  74.430845
# 19   13.298976  74.255336
# 20   13.316290  74.079828
# 21   13.333605  73.904319
# 22   13.350919  73.728811
# 23   13.368234  73.553302
# 24   13.385548  73.377793
# 25   13.402863  73.202285
# 26   13.420177  73.026776
# 27   13.437492  72.851268
# 28   13.454806  72.675759
# 29   13.472121  72.500250
# ..         ...        ...
# 970  29.765079 -92.653350
# 971  29.782394 -92.828859
# 972  29.799708 -93.004368
# 973  29.817023 -93.179876
# 974  29.834337 -93.355385
# 975  29.851652 -93.530893
# 976  29.868966 -93.706402
# 977  29.886281 -93.881911
# 978  29.903595 -94.057419
# 979  29.920910 -94.232928
# 980  29.938224 -94.408436
# 981  29.955539 -94.583945
# 982  29.972853 -94.759454
# 983  29.990168 -94.934962
# 984  30.007482 -95.110471
# 985  30.024797 -95.285979
# 986  30.042111 -95.461488
# 987  30.059426 -95.636997
# 988  30.076740 -95.812505
# 989  30.094055 -95.988014
# 990  30.111369 -96.163523
# 991  30.128684 -96.339031
# 992  30.145998 -96.514540
# 993  30.163313 -96.690048
# 994  30.180627 -96.865557
# 995  30.197942 -97.041066
# 996  30.215256 -97.216574
# 997  30.232571 -97.392083
# 998  30.249885 -97.567591
# 999  30.267200 -97.743100
#
# [1000 rows x 2 columns]
